# %% [markdown]
# ## This document performs the data preprocessing of toronto yelp data

# %%
from ast import literal_eval
from os import listdir
from os.path import isfile, join
from scipy.sparse import csr_matrix, load_npz, save_npz
from tqdm import tqdm
from sklearn.preprocessing import normalize
import yaml
import seaborn as sns
import datetime
import json
import numpy as np
import pandas as pd
import time
import yaml
import scipy.sparse as sparse
from ast import literal_eval

# %% [markdown]
# ### Load Toronto Data, review as df_toronto_review and business as df_business
# #### (Import Toronto data as df,  userJson as df_user)

# %%
# read csv data reviews 
df_toronto_review = pd.read_csv('../data/toronto_reviews.csv')

# read business csv data 
df_business = pd.read_csv('../data/businesses_final_toronto.csv')

# %%
df_toronto_review.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1             business_id  friend_count  ghost  \
# 0           0             0  bSQGCheX1BwvL67Az1OJlA            90  False
# 1           1             1  bSQGCheX1BwvL67Az1OJlA             0  False
#
#   img_dsc img_url     nr  photo_count  rating  ...  review_language  \
# 0      []      []  False        231.0     5.0  ...               en
# 1      []      []  False          9.0     1.0  ...               en
#
#                                          review_text          ufc  \
# 0  I had a good experience at this store. I was g...  [10, 1, 10]
# 1  I reaaaaaally wish I had read all the stories ...    [0, 0, 0]
#
#                   user_id         user_loc vote_count Updated  Year  Month  \
# 0  q41qqkChL9fRxF43cnkgbw      Houston, TX       11.0   False  2018      5
# 1  tNT5I9-QcljS-7w_doXCXQ  Toronto, Canada        0.0   False  2018      6
#
#    Day
# 0    9
# 1    3
#
# [2 rows x 23 columns]

# %%
len(df_toronto_review)
# Out:
# 747183

# %%
df_toronto_review.user_id.unique().size
# Out:
# 128420

# %%
# rename business id
df_business.rename(columns={'id': 'business_id'}, inplace=True)

# %%
df_business.head(2)
# Out:
#    Unnamed: 0                    alias  \
# 0           0    the-ossington-toronto
# 1           1  life-is-sweet-toronto-3
#
#                                           categories  \
# 0      [{'alias': 'divebars', 'title': 'Dive Bars'}]
# 1  [{'alias': 'desserts', 'title': 'Desserts'}, {...
#
#                                          coordinates    display_phone  \
# 0      {'latitude': 43.6456, 'longitude': -79.41903}  +1 416-850-0161
# 1  {'latitude': 43.67212500034, 'longitude': -79....  +1 416-698-0555
#
#       distance             business_id  \
# 0  4831.221092  KUdj08tVC3tvIT0rM6V8uQ
# 1  1716.906703  rnjFHvb1I-KlnGvv_o_Zxg
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/dEQPAb...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/s11QxZ...      False
#
#                                             location           name  \
# 0  {'address1': '61 Ossington Avenue', 'address2'...  The Ossington
# 1  {'address1': '2345 Queen Street E', 'address2'...  Life is Sweet
#
#           phone price  rating  review_count transactions  \
# 0  1.416850e+10    $$     3.0            46           []
# 1  1.416698e+10    $$     4.0            10           []
#
#                                                  url
# 0  https://www.yelp.com/biz/the-ossington-toronto...
# 1  https://www.yelp.com/biz/life-is-sweet-toronto...

# %%
print("total business numbers:", len(df_business))
# Out:
# total business numbers: 32123

# %% [markdown]
# ## Checking all unique categories

# %%
import re

# %%
df_business.categories.unique().size
# Out:
# 7197

# %%
categories_list = list(df_business.categories.unique())

# %%
categories_list[65]
# Out:
# "[{'alias': 'acupuncture', 'title': 'Acupuncture'}, {'alias': 'reflexology', 'title': 'Reflexology'}, {'alias': 'massage_therapy', 'title': 'Massage Therapy'}]"

# %%
res = re.findall(r'\w+', categories_list[65])

# %%
print ("The list of words is : " +  str(res))
# Out:
# The list of words is : ['alias', 'acupuncture', 'title', 'Acupuncture', 'alias', 'reflexology', 'title', 'Reflexology', 'alias', 'massage_therapy', 'title', 'Massage', 'Therapy']

# %%
res[2] != 'title'
# Out:
# False

# %%
new_categories_list = []
for category in categories_list:
    res = re.findall(r'\w+', category)
    for word in res:
        if (word != 'alias') and (word != 'title'):
            new_categories_list.append(word)

# %%
set(new_categories_list)
# Out:
# {'playgrounds',
#  'estatephotography',
#  'french',
#  'Commissioned',
#  'criminaldefense',
#  'midwives',
#  'Housing',
#  'paintyourownpottery',
#  'alternativemedicine',
#  'hypnosis',
#  'Montessori',
#  'Macarons',
#  'cookingschools',
#  'medcenters',
#  'Stationery',
#  'active',
#  'Mexican',
#  'Rafting',
#  'permanentmakeup',
#  'petboarding',
#  'modern_european',
#  'Playgrounds',
#  'homecleaning',
#  'Campgrounds',
#  'Boating',
#  'Live',
#  'laotian',
#  'Wineries',
#  'apartments',
#  'localflavor',
#  'Sitting',
#  'Auditors',
#  'scottish',
#  'Language',
#  'Muay',
#  'tanningbeds',
#  'malaysian',
#  'internetcafe',
#  'specialed',
#  'petbreeders',
#  'Treatment',
#  'ayurveda',
#  'Embassy',
#  'Jewelry',
#  'Coffee',
#  'Driving',
#  'Badminton',
#  'contractors',
#  'haitian',
#  'Lebanese',
#  'General',
#  'Teachers',
#  'sharedofficespaces',
#  'hookah_bars',
#  'blowoutservices',
#  'Credit',
#  'pilates',
#  'Store',
#  'Russian',
#  'Fidelity',
#  'hydroponics',
#  'indoor_playcenter',
#  'cosmeticsurgeons',
#  'Gardeners',
#  'dentalhygienists',
#  'hakka',
#  'Print',
#  'security',
#  'Body',
#  'roofing',
#  'sushi',
#  'Protection',
#  'Pubs',
#  'bbq',
#  'Organization',
#  'busstations',
#  'Pottery',
#  'legalservices',
#  '3dprinting',
#  'Decorating',
#  'electronics',
#  'Psychologists',
#  'importedfood',
#  'day',
#  'psychicmediums',
#  'Noodles',
#  'videogamestores',
#  'Activities',
#  'Fish',
#  'paydayloans',
#  'lounges',
#  '3D',
#  'thrift_stores',
#  'DUI',
#  'Hearing',
#  'Interior',
#  'urgent_care',
#  'Pet',
#  'refinishing',
#  'Nose',
#  'Trophy',
#  'Ukrainian',
#  'Plastic',
#  'escapegames',
#  'Insurance',
#  'Tobacco',
#  'Waffles',
#  'taichi',
#  'Couriers',
#  'retirement_homes',
#  'Salons',
#  'Alternative',
#  'Donairs',
#  'Door',
#  'Flavor',
#  'Books',
#  'Paintball',
#  'bagels',
#  'carshares',
#  'paintstores',
#  'Legal',
#  'speakeasies',
#  'Post',
#  'Thrift',
#  'Austrian',
#  'Climbing',
#  'Organizations',
#  'furniture',
#  'thai',
#  'personalchefs',
#  'Bars',
#  'hotpot',
#  'swimmingpools',
#  'Airport',
#  'Latin',
#  'dimsum',
#  'batterystores',
#  'persian',
#  'Chips',
#  'Haitian',
#  'othersalons',
#  'Recording',
#  'surfschools',
#  'menscloth',
#  'Acne',
#  'Street',
#  'tabletopgames',
#  'taekwondo',
#  'Stores',
#  'Aquariums',
#  'taxservices',
#  'shavedsnow',
#  'Gear',
#  'Psychic',
#  'currencyexchange',
#  'Caribbean',
#  'football',
#  'laundromat',
#  'homeappliancerepair',
#  'artschools',
#  'Self',
#  'orthopedists',
#  'Dumpster',
#  'Imported',
#  'trampoline',
#  'financialadvising',
#  'militarysurplus',
#  'cambodian',
#  'Spa',
#  'Conditioning',
#  'videofilmproductions',
#  'beachequipmentrental',
#  'Safety',
#  'Loan',
#  'communitycenters',
#  'Pediatric',
#  'Hypnosis',
#  'TV',
#  'Tenant',
#  'Sri',
#  'Mirrors',
#  'car_dealers',
#  'bikes',
#  'Psychiatrists',
#  'Animal',
#  'Chicken',
#  'petadoption',
#  'Kayaking',
#  'carousels',
#  'ramen',
#  'airsoft',
#  'Aquarium',
#  'beertours',
#  'Antiques',
#  'aquariumservices',
#  'Beaches',
#  'Electricians',
#  'trailerrental',
#  'Clothing',
#  'Charters',
#  'mongolian',
#  'passportvisaservices',
#  'Waxing',
#  'pediatric_dentists',
#  'snorkeling',
#  'peruvian',
#  'Festivals',
#  'christmastrees',
#  'Installation',
#  'hepatologists',
#  'virtualrealitycenters',
#  'Fields',
#  'Go',
#  'libraries',
#  'cabinetry',
#  'Party',
#  'Loans',
#  'Town',
#  'shutters',
#  'Check',
#  'Personal',
#  'Profit',
#  'landmarks',
#  'Characters',
#  'beautysvc',
#  'Education',
#  'walkinclinics',
#  'african',
#  'auto_detailing',
#  'seasonaldecorservices',
#  'asianfusion',
#  'Appraisal',
#  'Allergists',
#  'Threading',
#  'taiwanese',
#  'Photographers',
#  'Career',
#  'salad',
#  'fooddeliveryservices',
#  'Instrument',
#  'Haunted',
#  'opticians',
#  'Hakka',
#  'indpak',
#  'realestatesvcs',
#  'irish_pubs',
#  'Organic',
#  'Real',
#  'Feng',
#  'Markets',
#  'Creperies',
#  'yoga',
#  'acaibowls',
#  'Delis',
#  'Booth',
#  'colonics',
#  'groutservices',
#  'Cleaning',
#  'Rooms',
#  'himalayan',
#  'awnings',
#  'cardioclasses',
#  'shoes',
#  'Do',
#  'pawn',
#  'mexican',
#  'Bartenders',
#  'food_court',
#  'professional',
#  'Eyebrow',
#  'financialservices',
#  'Sex',
#  'Electronics',
#  'airports',
#  'Balloon',
#  'Vape',
#  'painmanagement',
#  'Reality',
#  'vacationrentalagents',
#  'Countertop',
#  'Testing',
#  'Fences',
#  'Fireworks',
#  'daycamps',
#  'businessfinancing',
#  'Disc',
#  'Bistros',
#  'venezuelan',
#  'trains',
#  'Systems',
#  'raw_food',
#  'kitchensupplies',
#  'suppliesrestaurant',
#  'Duct',
#  'eventplanning',
#  'Camps',
#  'buffets',
#  'reflexology',
#  'shoerepair',
#  'Life',
#  'Mini',
#  'Flowers',
#  'poolcleaners',
#  'piercing',
#  'freediving',
#  'nonprofit',
#  'educationservices',
#  'delicatessen',
#  'Ultrasound',
#  'Tinting',
#  'Laundromat',
#  'tattooremoval',
#  'Commercial',
#  'Museums',
#  'Pets',
#  'Rental',
#  'Bowls',
#  'allergist',
#  'immigrationlawyers',
#  'Debt',
#  'Pools',
#  'Nanny',
#  'Trusts',
#  'Blues',
#  'champagne_bars',
#  'embroideryandcrochet',
#  'auto',
#  'Comic',
#  'Ice',
#  'Estate',
#  'hotels',
#  'Auction',
#  'Imaging',
#  'Tai',
#  'Carpenters',
#  'Walking',
#  'printmedia',
#  'Police',
#  'garage_door_services',
#  'Games',
#  'Outlet',
#  'waterparks',
#  'dance_schools',
#  'Cleaners',
#  'Duty',
#  'flowers',
#  'hair',
#  'nephrologists',
#  'Scooter',
#  'Sewing',
#  'payroll',
#  'butcher',
#  'Shelters',
#  'Christmas',
#  'massage_therapy',
#  'Technical',
#  'Colombian',
#  'blinds',
#  'Axe',
#  'holidaydecorations',
#  'healthtrainers',
#  'Greek',
#  'Thai',
#  'Buses',
#  'Trucks',
#  'stereo_installation',
#  'Fusion',
#  'Insulation',
#  'Shops',
#  'officiants',
#  'fabricstores',
#  'emergencypethospital',
#  'Breakfast',
#  'Holistic',
#  'autorepair',
#  'wildlifecontrol',
#  'Piano',
#  'Fireplace',
#  'Landscaping',
#  'customcakes',
#  'motorcyclerepair',
#  'Halls',
#  'Control',
#  'Traditional',
#  'Hats',
#  'embassy',
#  'pest_control',
#  'waterproofing',
#  'karaoke',
#  'Propane',
#  'Home',
#  'Riding',
#  'icecream',
#  'hair_extensions',
#  'Medicine',
#  'movietheaters',
#  'sunglasses',
#  'Stucco',
#  'makeupartists',
#  'spas',
#  'Pakistani',
#  'Parts',
#  'Small',
#  'salvadoran',
#  'Heating',
#  'luggagestorage',
#  'Peruvian',
#  'Team',
#  'Movers',
#  'Farmers',
#  'Public',
#  'boating',
#  'Cream',
#  'fitnessequipment',
#  'Gold',
#  'truck_rental',
#  'Carpet',
#  'Vocational',
#  'Swimwear',
#  'Comedy',
#  'gyms',
#  'churches',
#  'Automotive',
#  'childcare',
#  'medicalsupplies',
#  'Coach',
#  'aquariums',
#  'Makeup',
#  'Customs',
#  'travelagents',
#  'Immigration',
#  'Mountain',
#  'Aviation',
#  'Matchmakers',
#  'servicestations',
#  'Rehabilitation',
#  'homeenergyauditors',
#  'education',
#  'Leather',
#  'zoos',
#  'Ski',
#  'trainstations',
#  'Gifts',
#  'Tapas',
#  'officecleaning',
#  'physicians',
#  'Pub',
#  'marketing',
#  'Audio',
#  'Kickboxing',
#  'Foundation',
#  'Doctors',
#  'Drywall',
#  'Cantonese',
#  'Trainers',
#  'Supplies',
#  'Uniforms',
#  'Fast',
#  'Embroidery',
#  'Purification',
#  'popupshops',
#  'adultentertainment',
#  'Rock',
#  'Car',
#  'grocery',
#  'Magicians',
#  'Condominiums',
#  'Graphic',
#  'photoclasses',
#  'greek',
#  'Arenas',
#  'Assembly',
#  'publicrelations',
#  'Mediterranean',
#  'Dinner',
#  'Eyelash',
#  'familydr',
#  'Stadiums',
#  'translationservices',
#  'Lawyers',
#  'Gift',
#  'vacation_rentals',
#  'Pressure',
#  'Eviction',
#  'careercounseling',
#  'vegetarian',
#  'Falafel',
#  'diners',
#  'damagerestoration',
#  'environmentaltesting',
#  'Lice',
#  'Biking',
#  'Hostels',
#  'recyclingcenter',
#  'hotdogs',
#  'stationery',
#  'waffles',
#  'Belgian',
#  'It',
#  'dog_parks',
#  'healthretreats',
#  'bubbletea',
#  'Agencies',
#  'australian',
#  'policedepartments',
#  'Pay',
#  'social_clubs',
#  'insurance',
#  'tex',
#  'campgrounds',
#  'rock_climbing',
#  'Arcades',
#  'floatspa',
#  'Up',
#  'hottubandpool',
#  'Retirement',
#  'artmuseums',
#  'Bubble',
#  'Restaurants',
#  'Gas',
#  'autosecurity',
#  'Brewpubs',
#  'up',
#  'Development',
#  'lancenters',
#  'mini_golf',
#  'Bespoke',
#  'Turkish',
#  'breweries',
#  'hotdog',
#  'Bookkeepers',
#  'generaldentistry',
#  'Art',
#  'Men',
#  'djs',
#  'Indonesian',
#  'furnitureassembly',
#  'Items',
#  'wallpapering',
#  'Shine',
#  'Screen',
#  'donuts',
#  'Cooking',
#  'afghani',
#  'macarons',
#  'Decor',
#  'officeequipment',
#  'candlestores',
#  'Fixtures',
#  'Product',
#  'Day',
#  'stucco',
#  'vinyl_records',
#  'golfequipment',
#  'Laotian',
#  'srilankan',
#  'cajun',
#  'pianobars',
#  'Motor',
#  'Summer',
#  'british',
#  'busrental',
#  'web_design',
#  'Barre',
#  'lakes',
#  'Vitamins',
#  'bankruptcy',
#  'Management',
#  'Solar',
#  'trailerdealers',
#  'fishing',
#  'wholesale_stores',
#  'Bookbinding',
#  'groomer',
#  'funeralservices',
#  'bespoke',
#  'Aestheticians',
#  'Developers',
#  'Pharmacy',
#  'casinos',
#  's',
#  'gametruckrental',
#  'Crafts',
#  'squash',
#  'Comfort',
#  'tcm',
#  'Iranian',
#  'Records',
#  'defense',
#  'Venezuelan',
#  'dermatology',
#  'Non',
#  'Veggies',
#  'observatories',
#  'limos',
#  'brewpubs',
#  'Pest',
#  'polish',
#  'Lakes',
#  'artsupplies',
#  'Washers',
#  'televisionserviceproviders',
#  'Rehearsal',
#  'Rinks',
#  'tradamerican',
#  'Sharing',
#  'skishops',
#  'waxing',
#  'podiatrists',
#  'Raw',
#  'Sporting',
#  'rafting',
#  'jazzandblues',
#  'Stereo',
#  'sportsteams',
#  'fireworks',
#  'Dietitians',
#  'dogwalkers',
#  'Tree',
#  'partycharacters',
#  'Recreation',
#  'Tutors',
#  'maternity',
#  'Cemeteries',
#  'Pool',
#  'Divorce',
#  'challengecourses',
#  'huntingfishingsupplies',
#  'falafel',
#  'fleamarkets',
#  'Bar',
#  'Gyms',
#  'and',
#  'Taiwanese',
#  'cocktailbars',
#  'discgolf',
#  'Spirits',
#  'excavationservices',
#  'reupholstery',
#  'acnetreatment',
#  'pianostores',
#  'enviroabatement',
#  'Coverings',
#  'Mongolian',
#  'barbers',
#  'catering',
#  'costumes',
#  'arcades',
#  'guesthouses',
#  'Agents',
#  'diagnosticservices',
#  'Goods',
#  'homestaging',
#  'Ophthalmologists',
#  'elementaryschools',
#  'Offices',
#  'Brunch',
#  'Tax',
#  'mags',
#  'synagogues',
#  'Special',
#  'Scuba',
#  'HVAC',
#  'belgian',
#  'Refinishing',
#  'gemstonesandminerals',
#  'Farming',
#  'Videos',
#  'hvac',
#  'Roasteries',
#  'Tub',
#  'Wildlife',
#  'autopartssupplies',
#  'vintage',
#  'Patisserie',
#  'outdoorgear',
#  'Wine',
#  'dancestudio',
#  'Beds',
#  'Jiu',
#  'nightlife',
#  'gastroenterologist',
#  'coffeeroasteries',
#  'Supernatural',
#  'Psychics',
#  'landscaping',
#  'diagnosticimaging',
#  'personal_injury',
#  'Caterers',
#  'Hospital',
#  'Social',
#  'tuina',
#  'Radio',
#  'Production',
#  'Nightlife',
#  'Flooring',
#  'doorsales',
#  'pubs',
#  'Supply',
#  'gymnastics',
#  'Mortgage',
#  'Dentists',
#  'Nurseries',
#  'Instruments',
#  'cosmetics',
#  'Educational',
#  'hindu_temples',
#  'Criminal',
#  'airportterminals',
#  'cupcakes',
#  'Hair',
#  'safestores',
#  'comedyclubs',
#  'Beauty',
#  'Painting',
#  'solarinstallation',
#  'Garage',
#  'Roofing',
#  'Trampoline',
#  'Excavation',
#  'Acupuncture',
#  'Vocal',
#  'Loss',
#  'Dog',
#  'Cinema',
#  'Architects',
#  'Women',
#  'Minerals',
#  'Instruction',
#  'mortgagebrokers',
#  'Urologists',
#  'Videographers',
#  'computers',
#  'Retreats',
#  'Film',
#  'Pop',
#  'Virtual',
#  'animalshelters',
#  'businessconsulting',
#  'Mailbox',
#  'cheese',
#  'scuba',
#  'Nepalese',
#  'customsbrokers',
#  'rvrepair',
#  'skincare',
#  'smog_check_stations',
#  'Safe',
#  'musicians',
#  'clothingrental',
#  'gluten_free',
#  'university_housing',
#  'Air',
#  'Shopping',
#  'general_litigation',
#  'Tours',
#  'Own',
#  'Energy',
#  'carbuyers',
#  'Facilities',
#  'Gardens',
#  'Contractors',
#  'Hygienists',
#  'Restaurant',
#  'driveintheater',
#  'Litigation',
#  'debtrelief',
#  'Windshield',
#  'Waste',
#  'Tasting',
#  'Cardiologists',
#  'Sledding',
#  'poutineries',
#  'Payroll',
#  'roadsideassist',
#  'lawyers',
#  'brewingsupplies',
#  'Southern',
#  'Community',
#  'sleepspecialists',
#  'Horseback',
#  'shredding',
#  'truckrepair',
#  'addictionmedicine',
#  'Laundry',
#  'Machine',
#  'homedecor',
#  'parks',
#  'german',
#  'Courses',
#  'Clock',
#  'hiking',
#  'Engraving',
#  'Baby',
#  'masonry_concrete',
#  'bikesharing',
#  'Investing',
#  'Advertising',
#  'Wholesale',
#  'eventservices',
#  'towing',
#  'Clowns',
#  'Firewood',
#  'Vehicle',
#  'Vinyl',
#  'Adult',
#  'Wallpapering',
#  'Fabric',
#  'Practice',
#  'Beach',
#  'Preschools',
#  'cantonese',
#  'supperclubs',
#  'tenantlaw',
#  'Skating',
#  'Notaries',
#  'orthodontists',
#  'drywall',
#  'scooterrentals',
#  'Pawn',
#  'Hiking',
#  'Churches',
#  'Drive',
#  'Airlines',
#  'beer_and_wine',
#  'bowling',
#  'Mass',
#  'endodontists',
#  'hobbyshops',
#  'signmaking',
#  'massmedia',
#  'Transportation',
#  'willstrustsprobates',
#  'Fire',
#  'Poke',
#  'Strip',
#  'Synagogues',
#  'Pot',
#  'festivals',
#  'towncarservice',
#  'Relief',
#  'painters',
#  'Radiologists',
#  'hospitals',
#  'divebars',
#  'Bakeries',
#  'newcanadian',
#  'arabian',
#  'mountainbiking',
#  'Emergency',
#  'firewood',
#  'axethrowing',
#  'paintball',
#  'Boxing',
#  'furniturerepair',
#  'Specialists',
#  'Cocktail',
#  'Soccer',
#  'chinesemartialarts',
#  'Sharpening',
#  'Hot',
#  'vinylsiding',
#  'Acai',
#  'Gastropubs',
#  'Tiki',
#  'RV',
#  'Vegetarian',
#  'Local',
#  'Trailer',
#  'brazilian',
#  'chiropractors',
#  'muaythai',
#  'interiordesign',
#  'cookingclasses',
#  'Paint',
#  'indonesian',
#  'Dentistry',
#  'architects',
#  'carpet_cleaning',
#  'Injury',
#  'Syrian',
#  'spiritual_shop',
#  'bustours',
#  'doulas',
#  'Dry',
#  'Gluten',
#  'occupationaltherapy',
#  'eyelashservice',
#  'Military',
#  'bridal',
#  'cannabis_clinics',
#  'Advising',
#  'productdesign',
#  'Butcher',
#  'Drugstores',
#  'toys',
#  'Stands',
#  'Internet',
#  'Out',
#  'Distilleries',
#  'meats',
#  'seafoodmarkets',
#  'Teeth',
#  'Repair',
#  'sewingalterations',
#  'Houses',
#  'pianoservices',
#  'spanish',
#  'carrental',
#  'Skate',
#  'Parks',
#  'Mental',
#  'shoppingcenters',
#  'Brokers',
#  'laser_hair_removal',
#  'bodyshops',
#  'Tabletop',
#  'magicians',
#  'Chimney',
#  'threadingservices',
#  'jetskis',
#  'Sweeps',
#  'Outdoor',
#  'Swimming',
#  'boatcharters',
#  'historicaltours',
#  'selfdefenseclasses',
#  'vapeshops',
#  'Sushi',
#  'Trains',
#  'advertising',
#  'homeservices',
#  'balloonservices',
#  'tours',
#  'locksmiths',
#  'luggage',
#  'kickboxing',
#  'Nail',
#  'Watch',
#  'poolbilliards',
#  'aviationservices',
#  'Musicians',
#  'screenprinting',
#  'Department',
#  'dryclean',
#  'osteopathicphysicians',
#  'photoboothrentals',
#  'floraldesigners',
#  'tapasmallplates',
#  'Podiatrists',
#  'home_organization',
#  'Grout',
#  'Diners',
#  'Crochet',
#  'Aid',
#  'Automation',
#  'Office',
#  'drugstores',
#  'landscapearchitects',
#  'brasseries',
#  'condominiums',
#  'Music',
#  'parking',
#  'University',
#  'telecommunications',
#  'Cafe',
#  'teambuilding',
#  'Windows',
#  'Waterproofing',
#  'artrestoration',
#  'Decorations',
#  'amateursportsteams',
#  'Banks',
#  'brazilianjiujitsu',
#  'Australian',
#  'waterheaterinstallrepair',
#  'Financial',
#  'sailing',
#  'DVDs',
#  'Makerspaces',
#  'bartendingschools',
#  'boxing',
#  'vitaminssupplements',
#  'hazardouswastedisposal',
#  'hkcafe',
#  'herbsandspices',
#  'Diagnostic',
#  'Apartments',
#  'Oil',
#  'Share',
#  'livestocksupply',
#  'southern',
#  'Government',
#  'Addiction',
#  'Lasik',
#  'waterpurification',
#  'Spiritual',
#  'Chocolatiers',
#  'Providers',
#  'stripclubs',
#  ...}

# %% [markdown]
# ## Data Processing

# %% [markdown]
# #### High level processsing

# %%
# keywords used to identify restaurants
restaurantString = "restaurant|Bar|Bakeries|food|Coffee|Tea|Waffles|Desserts\
|sandwiches|Cupcakes|cafes|Breakfast|Brunch|Lunch|Dinner|chicken|wings\
|singaporean|malaysian|indonesian|russian|taiwanese|american|vietnamese|moroccan\
|cantonese|caribbean|mideastern|asian|italian|korean|himalayan|african|nepalese|laotian|sushi|hawaiian\
|mediterranean|caterers|fish|chips|fishnchips|thai|salad|chinese|seafood|irish|portuguese|french|vegan|raw_food\
|pizza|latin|lebanese|burgers|gluten-free|japanese|pakistani|mexican|sushi|argentine|lounges|barbeque\
|canadian|dimsum|halal|afghan|donuts|juice|smoothies|bagels|ramen|icecream|pubs|falafel\
|noodles|soup|cheese|colombian|turkish|ethiopian|peruvian|hungarian|ukrainian|indian\
|persian|brazilian|vegetarian|austrian|arabian|haitian|cambodian|german|greek|Barbeque|Buffets\
|Cajun/Creole|Cajun|Cuban|Czech|Delis|Diners|Filipino|Festivals|Hot Dogs|Hot Pot|Macarons|Modern European\
|Nightlife|Salvadoran|Venezuelan|tapas|australian|kosher|wine|creperies|cafe|bangladeshi|cakes|brasseries\
|cideries|smokehouse|patisserie|hindu|hong kong|hakka|veggies|plates|hkcafe|spanish|grilling"

# We only take restaurant business with the above keywords
cond_category_restaurant = df_business["categories"].str.contains(restaurantString,case=False)

#df_business_Restaurant = df_business[cond_category_restaurant]
df_matched_business = df_business[cond_category_restaurant]

# keywords used to identify businesses we want to filter out
filterString = "acupuncture|grocery|bookstores|musicvideo|yoga|servicestations|convenience|homeappliancerepair\
|appliances|Repair|bike|repair|Used|toys|wholesale|supplies|hair|barbers|Hair Salons|Archery|Adult Entertainment|Amateur Sports Teams\
|Airport Lounges|Vinyl Records|Pilates|fitness|Real Estate Agents|Real Estate Services|Recreation Centers|Reflexology\
|massage|Tattoo|Traditional Chinese Medicine|Trainers|Walking Tours|Virtual Reality Centers|Musical Instrument Services|Laser Tag\
|Community Service/Non-Profit|Flea Markets|Tours|Golf|Hotels|Kids Activities|Accessories|Bartending Schools|audio|foodbanks\
|barreclasses|bartenders|kitchenandbath|cosmetics|Bed & Breakfast|bowling|boxing|teambuilding|casinos|Centers|movietheaters\
|musicalinstrumentsandteachers|colleges|couriers|Customized Merchandise|gyms|escapegames|videogamestores|gift|goods|laundromat\
|martial|muaythai|eventplanning|Performing Arts|personalchefs|pets|piano|sportsteams|schools|spas|tobaccoshops|vape|wedding_planning\
|winetours|beer_and_wine|Wineries|hvac|winetastingroom|hindu_temples|fireplace|artclasses|Arcades|galleries|Personal Shopping|Strip Clubs\
|grillingequipment|herbsandspices|bubbletea"

df_business_Restaurant = df_matched_business[~df_matched_business["categories"].str.contains(filterString,case=False)]

print('Matched categories, before filtering size: ', len(df_matched_business))
print('Matched categories, after filtering size: ', len(df_business_Restaurant))
# Out:
# Matched categories, before filtering size:  10422
# Matched categories, after filtering size:  9106

# %% [markdown]
# #### Exclude Catering Category

# %%
df_business_Restaurant = df_business_Restaurant[~(df_matched_business["price"].isna() & \
                                               df_matched_business["categories"].str.contains("cater",case=False))]
print('Matched categories, after filtering size: ', len(df_business_Restaurant))
# Out:
# Matched categories, after filtering size:  8972
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# #### Exclude Food Deliver Service

# %%
df_business_Restaurant = df_business_Restaurant[~((df_matched_business["review_count"] <= 6) & \
                                                  df_matched_business["categories"].str.contains("fooddeliveryservices",case=False))]
                                    
print('Matched categories, after filtering size: ', len(df_business_Restaurant))
# Out:
# Matched categories, after filtering size:  8933
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# #### Filter out specific restaurants

# %%
filtered_out_restaurant = "8090-ktv-toronto|soho-ktv|prestige-by-night-toronto|hard-luck-bar|ktv|mimico-pub-and-grill|bar-karaoke-lounge\
                            |lighthouse-shisha-lounge|arabica-lounge|Purdy|dried-nuts-and-fruits|tangs-company|the-painted-lady|baby-g\
                            |Coalition|bassline-music-bar|underground-garage|cadillac-lounge|internet-cafe|super-tech|netconnect-cafe|invictus\
                            |gigabites|internet|penta-q|freshly-squeezed-toronto"

# %%
df_business_Restaurant = df_business_Restaurant[~(df_matched_business["alias"].str.contains(filtered_out_restaurant,case=False))]
                                    
print('Matched categories, after filtering size: ', len(df_business_Restaurant))
# Out:
# Matched categories, after filtering size:  8903
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### Adding back specific restaurants

# %%
include_restaurant = "tasty-pot|pho-saigon-restaurant|kin-kin-bakery-and-bubble-tea|hk-sweets|mika-sushi\
                      |next-station|green-grotto"

# %%
df_business_Restaurant = df_business_Restaurant.append(df_matched_business[(df_matched_business["alias"].str.contains(include_restaurant,case=False))])
                                    
print('Matched categories, after filtering size: ', len(df_business_Restaurant))
# Out:
# Matched categories, after filtering size:  8919

# %% [markdown]
# #### Check review number

# %%
# df_business_Restaurant = df_business_Restaurant[~(df_matched_business["review_count"] < 8)]
                                    
# print('Matched categories, after filtering size: ', len(df_business_Restaurant))

# %% [markdown]
# ### Check the remaining categories

# %%
categories_list_final1 = list(df_business_Restaurant.categories.unique())
new_unique_categories_list = []
for category in categories_list_final1:
    res = re.findall(r'\w+', category)
    for word in res:
        if (word != 'alias') and (word != 'title'):
            new_unique_categories_list.append(word)

# %%
set(new_unique_categories_list)
# Out:
# {'Acai',
#  'Afghan',
#  'African',
#  'American',
#  'Antiques',
#  'Arabian',
#  'Argentine',
#  'Asian',
#  'Australian',
#  'Austrian',
#  'Bagels',
#  'Bakeries',
#  'Bangladeshi',
#  'Bar',
#  'Barbeque',
#  'Bars',
#  'Beer',
#  'Belgian',
#  'Bistros',
#  'Blues',
#  'Bowls',
#  'Brasseries',
#  'Brazilian',
#  'Breakfast',
#  'Breweries',
#  'Brewpubs',
#  'British',
#  'Brunch',
#  'Bubble',
#  'Buffets',
#  'Burgers',
#  'Burmese',
#  'Butcher',
#  'Cafe',
#  'Cafes',
#  'Cajun',
#  'Cake',
#  'Cakes',
#  'Cambodian',
#  'Canadian',
#  'Candy',
#  'Cannabis',
#  'Cantonese',
#  'Caribbean',
#  'Caterers',
#  'Champagne',
#  'Cheese',
#  'Cheesesteaks',
#  'Chicken',
#  'Chinese',
#  'Chips',
#  'Chocolatiers',
#  'Cideries',
#  'Classes',
#  'Clinics',
#  'Clubs',
#  'Cocktail',
#  'Coffee',
#  'Colombian',
#  'Comedy',
#  'Comfort',
#  'Cooking',
#  'Court',
#  'Cream',
#  'Creole',
#  'Creperies',
#  'Cuban',
#  'Cupcakes',
#  'Custom',
#  'Czech',
#  'Dance',
#  'Delicatessen',
#  'Delis',
#  'Delivery',
#  'Desserts',
#  'Dim',
#  'Diners',
#  'Dinner',
#  'Dive',
#  'Do',
#  'Dogs',
#  'Donairs',
#  'Donuts',
#  'Eastern',
#  'Egyptian',
#  'Ethiopian',
#  'European',
#  'Event',
#  'Falafel',
#  'Farmers',
#  'Fast',
#  'Festivals',
#  'Filipino',
#  'Fish',
#  'Fishing',
#  'Florists',
#  'Food',
#  'Free',
#  'French',
#  'Frozen',
#  'Fruits',
#  'Fusion',
#  'Games',
#  'Gastropubs',
#  'Gay',
#  'German',
#  'Gluten',
#  'Greek',
#  'Haitian',
#  'Hakka',
#  'Halal',
#  'Halls',
#  'Hawaiian',
#  'Health',
#  'Himalayan',
#  'Hong',
#  'Hookah',
#  'Hot',
#  'Hungarian',
#  'Ice',
#  'Imported',
#  'Indian',
#  'Indonesian',
#  'International',
#  'Internet',
#  'Iranian',
#  'Irish',
#  'It',
#  'Italian',
#  'Japanese',
#  'Jazz',
#  'Jiu',
#  'Juice',
#  'Karaoke',
#  'Kebab',
#  'Kong',
#  'Korean',
#  'Kosher',
#  'Lankan',
#  'Laotian',
#  'Latin',
#  'Lebanese',
#  'Live',
#  'Lounges',
#  'Macarons',
#  'Malaysian',
#  'Market',
#  'Markets',
#  'Meat',
#  'Mediterranean',
#  'Mex',
#  'Mexican',
#  'Middle',
#  'Modern',
#  'Mongolian',
#  'Moroccan',
#  'Music',
#  'Nepalese',
#  'New',
#  'Nicaraguan',
#  'Nightlife',
#  'Noodles',
#  'Organic',
#  'Pakistani',
#  'Pan',
#  'Patisserie',
#  'Persian',
#  'Peruvian',
#  'Pizza',
#  'Plates',
#  'Poke',
#  'Polish',
#  'Pool',
#  'Pop',
#  'Portuguese',
#  'Pot',
#  'Poutineries',
#  'Pub',
#  'Pubs',
#  'Ramen',
#  'Raw',
#  'Restaurants',
#  'Reunion',
#  'Roasteries',
#  'Rooms',
#  'Russian',
#  'Salad',
#  'Salvadoran',
#  'Sandwiches',
#  'Scottish',
#  'Seafood',
#  'Services',
#  'Shaved',
#  'Shop',
#  'Shopping',
#  'Shops',
#  'Singaporean',
#  'Slovakian',
#  'Small',
#  'Smokehouse',
#  'Smoothies',
#  'Snow',
#  'Social',
#  'Soul',
#  'Soup',
#  'South',
#  'Southern',
#  'Spaces',
#  'Spanish',
#  'Specialty',
#  'Sports',
#  'Sri',
#  'Stands',
#  'Steakhouses',
#  'Stores',
#  'Street',
#  'Style',
#  'Sum',
#  'Supper',
#  'Sushi',
#  'Syrian',
#  'Tabletop',
#  'Taiwanese',
#  'Tapas',
#  'Tea',
#  'Tex',
#  'Thai',
#  'Theater',
#  'Tiki',
#  'Traditional',
#  'Trucks',
#  'Turkish',
#  'Ukrainian',
#  'Up',
#  'Vegan',
#  'Vegetarian',
#  'Veggies',
#  'Vendors',
#  'Venezuelan',
#  'Venues',
#  'Vietnamese',
#  'Waffles',
#  'Whiskey',
#  'Wine',
#  'Wings',
#  'Yogurt',
#  'Yourself',
#  'acaibowls',
#  'afghani',
#  'african',
#  'antiques',
#  'arabian',
#  'argentine',
#  'asianfusion',
#  'australian',
#  'austrian',
#  'bagels',
#  'bakeries',
#  'bangladeshi',
#  'bars',
#  'bbq',
#  'beerbar',
#  'belgian',
#  'bistros',
#  'brasseries',
#  'brazilian',
#  'brazilianjiujitsu',
#  'breakfast_brunch',
#  'breweries',
#  'brewpubs',
#  'british',
#  'bubbletea',
#  'buffets',
#  'burgers',
#  'burmese',
#  'butcher',
#  'cafes',
#  'cajun',
#  'cakeshop',
#  'cambodian',
#  'candy',
#  'cannabis_clinics',
#  'cantonese',
#  'caribbean',
#  'catering',
#  'champagne_bars',
#  'cheese',
#  'cheesesteaks',
#  'chicken_wings',
#  'chickenshop',
#  'chinese',
#  'chocolate',
#  'cideries',
#  'cocktailbars',
#  'coffee',
#  'coffeeroasteries',
#  'colombian',
#  'comedyclubs',
#  'comfortfood',
#  'cookingclasses',
#  'creperies',
#  'cuban',
#  'cupcakes',
#  'customcakes',
#  'czech',
#  'danceclubs',
#  'delicatessen',
#  'delis',
#  'desserts',
#  'dimsum',
#  'diners',
#  'dinnertheater',
#  'divebars',
#  'diyfood',
#  'donairs',
#  'donuts',
#  'egyptian',
#  'ethiopian',
#  'falafel',
#  'farmersmarket',
#  'festivals',
#  'filipino',
#  'fishing',
#  'fishnchips',
#  'florists',
#  'food',
#  'food_court',
#  'fooddeliveryservices',
#  'foodstands',
#  'foodtrucks',
#  'french',
#  'gastropubs',
#  'gaybars',
#  'german',
#  'gluten_free',
#  'gourmet',
#  'greek',
#  'haitian',
#  'hakka',
#  'halal',
#  'hawaiian',
#  'healthmarkets',
#  'himalayan',
#  'hkcafe',
#  'hookah_bars',
#  'hotdog',
#  'hotdogs',
#  'hotpot',
#  'hungarian',
#  'icecream',
#  'importedfood',
#  'indonesian',
#  'indpak',
#  'international',
#  'internetcafe',
#  'irish',
#  'irish_pubs',
#  'italian',
#  'japanese',
#  'jazzandblues',
#  'jitsu',
#  'juicebars',
#  'karaoke',
#  'kebab',
#  'korean',
#  'kosher',
#  'laotian',
#  'latin',
#  'lebanese',
#  'lounges',
#  'macarons',
#  'malaysian',
#  'markets',
#  'meats',
#  'mediterranean',
#  'mex',
#  'mexican',
#  'mideastern',
#  'modern_european',
#  'mongolian',
#  'moroccan',
#  'musicvenues',
#  'newcanadian',
#  'nicaraguan',
#  'nightlife',
#  'noodles',
#  'organic_stores',
#  'pakistani',
#  'panasian',
#  'persian',
#  'peruvian',
#  'pizza',
#  'poke',
#  'polish',
#  'poolhalls',
#  'popuprestaurants',
#  'popupshops',
#  'portuguese',
#  'poutineries',
#  'pubs',
#  'ramen',
#  'raw_food',
#  'restaurants',
#  'reunion',
#  'russian',
#  'salad',
#  'salvadoran',
#  'sandwiches',
#  'scottish',
#  'seafood',
#  'seafoodmarkets',
#  'shavedsnow',
#  'shopping',
#  'singaporean',
#  'slovakian',
#  'smokehouse',
#  'social_clubs',
#  'soulfood',
#  'soup',
#  'southafrican',
#  'southern',
#  'spanish',
#  'sports_clubs',
#  'sportsbars',
#  'srilankan',
#  'steak',
#  'streetvendors',
#  'supperclubs',
#  'sushi',
#  'syrian',
#  'tabletopgames',
#  'taiwanese',
#  'tapas',
#  'tapasmallplates',
#  'tea',
#  'tex',
#  'thai',
#  'tikibars',
#  'tradamerican',
#  'turkish',
#  'ukrainian',
#  'up',
#  'vegan',
#  'vegetarian',
#  'venezuelan',
#  'venues',
#  'vietnamese',
#  'waffles',
#  'whiskeybars',
#  'wine_bars'}

# %% [markdown]
# ### Find if there are any not counted restaurant

# %%
#Checking the filtered out businesses at the first step to see if missed any restaurants
cond_category_Not_restaurant = ~df_business["categories"].str.contains(restaurantString,case=False)
business_not_res = df_business[cond_category_Not_restaurant]
# for index, value in business_not_res['categories'].items():
#     print("Index : {}, Value : {}".format(index, value))

# %%
df_cond_category_Not_restaurant = df_business[~df_business["categories"].str.contains(restaurantString,case=False)]
df_cond_category_Not_restaurant_2 = df_cond_category_Not_restaurant[~df_cond_category_Not_restaurant["categories"].str.contains(filterString,case=False)]

# %%
df_cond_category_Not_restaurant_2.head(1)
# Out:
#    Unnamed: 0                        alias  \
# 4           4  locksmith-vaughan-vaughan-3
#
#                                           categories  \
# 4  [{'alias': 'locksmiths', 'title': 'Keys & Lock...
#
#                                          coordinates    display_phone  \
# 4  {'latitude': 43.7975922, 'longitude': -79.4397...  +1 416-477-5464
#
#        distance             business_id  \
# 4  17551.531314  Smw9D566sGyeatfttpzb7Q
#
#                                            image_url  is_closed  \
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/Xpj30m...      False
#
#                                             location               name  \
# 4  {'address1': '', 'address2': None, 'address3':...  Locksmith Vaughan
#
#           phone price  rating  review_count transactions  \
# 4  1.416478e+10   NaN     5.0             1           []
#
#                                                  url
# 4  https://www.yelp.com/biz/locksmith-vaughan-vau...

# %%
categories_list_final2 = list(df_cond_category_Not_restaurant_2.categories.unique())
new_unique_categories_list = []
for category in categories_list_final2:
    res = re.findall(r'\w+', category)
    for word in res:
        if (word != 'alias') and (word != 'title'):
            new_unique_categories_list.append(word)

# %%
print(set(new_unique_categories_list))
# Out:
# {'playgrounds', 'estatephotography', 'Commissioned', 'criminaldefense', 'midwives', 'Housing', 'paintyourownpottery', 'alternativemedicine', 'hypnosis', 'Stationery', 'active', 'Rafting', 'permanentmakeup', 'petboarding', 'Playgrounds', 'homecleaning', 'Campgrounds', 'Boating', 'apartments', 'localflavor', 'Sitting', 'Auditors', 'tanningbeds', 'specialed', 'petbreeders', 'Treatment', 'ayurveda', 'Embassy', 'Jewelry', 'Badminton', 'contractors', 'General', 'sharedofficespaces', 'blowoutservices', 'Credit', 'Store', 'hydroponics', 'indoor_playcenter', 'Gardeners', 'dentalhygienists', 'Print', 'security', 'Body', 'roofing', 'Protection', 'Organization', 'busstations', 'Pottery', 'legalservices', '3dprinting', 'Decorating', 'electronics', 'Psychologists', 'day', 'psychicmediums', 'paydayloans', '3D', 'DUI', 'thrift_stores', 'Hearing', 'Interior', 'urgent_care', 'Pet', 'refinishing', 'Nose', 'Trophy', 'Plastic', 'Insurance', 'taichi', 'retirement_homes', 'Salons', 'Alternative', 'Door', 'Flavor', 'Books', 'Paintball', 'carshares', 'paintstores', 'Legal', 'speakeasies', 'Post', 'Thrift', 'Climbing', 'Organizations', 'furniture', 'swimmingpools', 'Airport', 'batterystores', 'othersalons', 'Recording', 'menscloth', 'Acne', 'Street', 'tabletopgames', 'taekwondo', 'Stores', 'Aquariums', 'taxservices', 'Gear', 'Psychic', 'currencyexchange', 'football', 'Self', 'orthopedists', 'Dumpster', 'trampoline', 'financialadvising', 'militarysurplus', 'Spa', 'videofilmproductions', 'Safety', 'beachequipmentrental', 'Loan', 'Pediatric', 'Hypnosis', 'TV', 'Tenant', 'Mirrors', 'car_dealers', 'Psychiatrists', 'Animal', 'petadoption', 'Kayaking', 'carousels', 'airsoft', 'Aquarium', 'Antiques', 'aquariumservices', 'Beaches', 'Electricians', 'trailerrental', 'Clothing', 'Charters', 'passportvisaservices', 'Waxing', 'pediatric_dentists', 'snorkeling', 'christmastrees', 'Installation', 'hepatologists', 'Fields', 'Go', 'libraries', 'cabinetry', 'Party', 'Loans', 'Town', 'shutters', 'Check', 'Personal', 'landmarks', 'Characters', 'Education', 'walkinclinics', 'auto_detailing', 'seasonaldecorservices', 'Appraisal', 'Allergists', 'Threading', 'Photographers', 'Career', 'Haunted', 'opticians', 'Organic', 'Real', 'Feng', 'Markets', 'Booth', 'colonics', 'groutservices', 'Cleaning', 'awnings', 'cardioclasses', 'shoes', 'pawn', 'professional', 'Eyebrow', 'financialservices', 'Electronics', 'airports', 'Balloon', 'painmanagement', 'vacationrentalagents', 'Countertop', 'Testing', 'Fences', 'Fireworks', 'daycamps', 'businessfinancing', 'trains', 'Systems', 'Duct', 'Camps', 'Life', 'poolcleaners', 'piercing', 'freediving', 'educationservices', 'delicatessen', 'Tinting', 'Commercial', 'Museums', 'Rental', 'allergist', 'immigrationlawyers', 'Debt', 'Pools', 'Nanny', 'Trusts', 'Blues', 'embroideryandcrochet', 'auto', 'Comic', 'Ice', 'Estate', 'Auction', 'Imaging', 'Tai', 'Carpenters', 'printmedia', 'Police', 'garage_door_services', 'Games', 'Outlet', 'waterparks', 'Cleaners', 'Duty', 'nephrologists', 'Scooter', 'Sewing', 'payroll', 'Christmas', 'butcher', 'Shelters', 'Technical', 'blinds', 'Axe', 'holidaydecorations', 'Buses', 'stereo_installation', 'Insulation', 'Shops', 'officiants', 'fabricstores', 'emergencypethospital', 'Holistic', 'wildlifecontrol', 'Landscaping', 'Halls', 'Control', 'Traditional', 'Hats', 'embassy', 'pest_control', 'waterproofing', 'karaoke', 'Propane', 'Home', 'Riding', 'Medicine', 'sunglasses', 'Stucco', 'makeupartists', 'luggagestorage', 'Movers', 'Public', 'Farmers', 'boating', 'Gold', 'truck_rental', 'Carpet', 'Vocational', 'Swimwear', 'Comedy', 'churches', 'Automotive', 'childcare', 'Coach', 'aquariums', 'Makeup', 'Customs', 'travelagents', 'Immigration', 'Mountain', 'Aviation', 'Matchmakers', 'Rehabilitation', 'homeenergyauditors', 'education', 'zoos', 'Ski', 'trainstations', 'officecleaning', 'physicians', 'marketing', 'Doctors', 'Uniforms', 'Embroidery', 'Purification', 'Rock', 'Car', 'Magicians', 'Condominiums', 'Graphic', 'photoclasses',  ...

# %% [markdown]
# ### Run this cell to check filtered out restaurants

# %%
# cat_set = []
# for cat in tqdm(business_not_res.categories.values):
#     temp = yaml.safe_load(cat)
# #     ans.append([temp[i]["title"] for i in range(len(temp))])
    
#     #loop through key, append title as categories 
#     for i in tqdm(range(len(temp))):
#         cat_set.append(temp[i]["title"])
# set(cat_set)

# %%
#Checking invalid businesses
#pd.options.display.max_colwidth = 90  
#set(df_business_Restaurant[df_business_Restaurant["categories"].str.contains('Qi Gong',case=False)].categories)

#checking original missed restaurants
#Czech
#df_business[df_business["categories"].str.contains('Venezuelan',case=False)]

# %%
# for index in range(0,100):
#     print(business_not_res['categories'][index])
#business_not_res['categories']

# for index, value in business_not_res['categories'].items():
#     print("Index : {}, Value : {}".format(index, value))

# %%
#Checking business name
# df_business['name'][31600]

# %%
# Drop duplicate values in df_business
print(len(df_business_Restaurant))
df_business_clean = df_business_Restaurant.drop_duplicates(subset ="business_id", 
                     keep = False)
print(len(df_business_clean))
df_business_clean = df_business_clean.reset_index()
# Out:
# 8919
# 8907

# %% [markdown]
# ## Separate out longitude and altitude

# %%
latitudeList = []
longitudeList = []

for business in range(len(df_business_clean)):
    latitude= yaml.safe_load(df_business_clean.coordinates[business])['latitude']
    longitude = yaml.safe_load(df_business_clean.coordinates[business])['longitude']
    latitudeList.append(latitude)
    longitudeList.append(longitude)

# %%
df_latitude = pd.DataFrame(np.asarray(latitudeList))
df_latitude.rename(columns={0: "latitude"}, inplace = True)
df_longitude = pd.DataFrame(np.asarray(longitudeList))
df_longitude.rename(columns={0: "longitude"}, inplace = True)

# %%
df_business_clean["latitude"] = df_latitude
df_business_clean["longitude"] = df_longitude
df_business_clean = df_business_clean.drop(df_business_clean[df_business_clean['longitude'] == 'None'].index)
df_business_clean = df_business_clean.drop(df_business_clean[df_business_clean['latitude'] == 'None'].index)
df_business_clean = df_business_clean.reset_index()

# %% [markdown]
# ## Changing the format of category

# %%
# Rename Month as Day and Day as Month(error occurs on original data)
df_toronto_review=df_toronto_review.rename(columns = {'Month':'new_Day'})
df_toronto_review=df_toronto_review.rename(columns = {'Day':'Month'})
df_toronto_review=df_toronto_review.rename(columns = {'new_Day':'Day'})

# %% [markdown]
# ### Merging review and business data

# %%
# inner join two full dataset
df = pd.merge(df_toronto_review, df_business_clean, on='business_id', how='inner')

# %%
df.shape
# Out:
# (493424, 43)

# %%
# merge the date and turn it into string
df['date'] = pd.to_datetime(df[['Year', 'Month','Day']])
df['date'] = df['date'].astype(str)

# %%
# rename the columns to match the algorithm 
df.rename(columns={'rating_x': 'stars','rating_y': 'business_stars','review_text': 'text',}, inplace=True)

# %%
# get rid of the rows without user_id
df = df[~df["user_id"].isnull()]

# %%
pd.set_option('display.max_columns', None)
df.head(2)
# Out:
#    Unnamed: 0_x  Unnamed: 0.1             business_id  friend_count  ghost  \
# 5            65            65  oRRCe6RruoHE1nMfTlMREA             0  False
# 6            66            66  oRRCe6RruoHE1nMfTlMREA            12  False
#
#   img_dsc img_url     nr  photo_count  stars  review_count_x  \
# 5      []      []  False          3.0    4.0               3
# 6      []      []  False          NaN    4.0               8
#
#            review_date               review_id review_language  \
# 5  ['9', '14', '2018']  dIaFxaGjQwrAAnKm57Se_w              en
# 6  ['5', '15', '2018']  ruTcyqV1E7UlOZ4I2ZLJHQ              en
#
#                                                 text        ufc  \
# 5  Cute location, however it is quite small. The ...  [0, 0, 0]
# 6  Pulled pork burger, salmon and cream cheese ba...  [1, 0, 0]
#
#                   user_id             user_loc  vote_count  Updated  Year  \
# 5  0HVBYtQOhI8sVc7n4bZxCw  Mississauga, Canada         0.0    False  2018
# 6  Qr5QmYRZHrh7zaqjYw63AQ      Toronto, Canada         1.0    False  2018
#
#    Day  Month  level_0  index  Unnamed: 0_y                    alias  \
# 5   14      9     1902   8511          8511  black-goat-cafe-toronto
# 6   15      5     1902   8511          8511  black-goat-cafe-toronto
#
#                                categories  \
# 5  [{'alias': 'cafes', 'title': 'Cafes'}]
# 6  [{'alias': 'cafes', 'title': 'Cafes'}]
#
#                                       coordinates    display_phone  \
# 5  {'latitude': 43.59672, 'longitude': -79.52254}  +1 416-792-7200
# 6  {'latitude': 43.59672, 'longitude': -79.52254}  +1 416-792-7200
#
#      distance                                          image_url  is_closed  \
# 5  5179.05848  https://s3-media2.fl.yelpcdn.com/bphoto/QWleI6...      False
# 6  5179.05848  https://s3-media2.fl.yelpcdn.com/bphoto/QWleI6...      False
#
#                                             location             name  \
# 5  {'address1': '3261 Lake Shore Boulevard W', 'a...  Black Goat Cafe
# 6  {'address1': '3261 Lake Shore Boulevard W', 'a...  Black Goat Cafe
#
#           phone price  business_stars  review_count_y transactions  \
# 5  1.416793e+10     $             3.5              17           []
# 6  1.416793e+10     $             3.5              17           []
#
#                                                  url  latitude  longitude  \
# 5  https://www.yelp.com/biz/black-goat-cafe-toron...  43.59672  -79.52254
# 6  https://www.yelp.com/biz/black-goat-cafe-toron...  43.59672  -79.52254
#
#          date
# 5  2018-09-14
# 6  2018-05-15

# %%
df = df.reset_index(drop=True)

# %%
dfff = df.copy()

# %% [markdown]
# change category format

# %%
#A list of categories
ans = []
for cat in tqdm(df.categories.values):
    temp = yaml.safe_load(cat)
#     ans.append([temp[i]["title"] for i in range(len(temp))])
    cat_str = ""
    #loop through key 
    for i in range(len(temp)):
        #if first element
        if i == 0:
            cat_str += temp[i]["title"]
            #if more than one title
            if len(temp) >1:
                cat_str += ", "
        #if last element
        elif i == len(temp)-1:
            cat_str += temp[i]["title"]
        else:
            cat_str += temp[i]["title"]
            cat_str += ", "
    ans.append(cat_str)
# Out:
# 100%|██████████| 402927/402927 [03:22<00:00, 1990.39it/s]

# %%
arr_temp = np.asarray(ans)

# %%
df_cat = pd.DataFrame(arr_temp)
df_cat.rename(columns={0: "cat"}, inplace = True)

# %%
#Create a new column for the review df
df["cat"] = df_cat

# %%
pd.set_option('display.max_rows', 100000)

# %%
#Delete original categories column
del df['categories']

# %%
df.rename(columns={"cat": "categories"}, inplace = True)

# %%
df.head(2)
# Out:
#    Unnamed: 0_x  Unnamed: 0.1             business_id  friend_count  ghost  \
# 0            65            65  oRRCe6RruoHE1nMfTlMREA             0  False
# 1            66            66  oRRCe6RruoHE1nMfTlMREA            12  False
#
#   img_dsc img_url     nr  photo_count  stars  review_count_x  \
# 0      []      []  False          3.0    4.0               3
# 1      []      []  False          NaN    4.0               8
#
#            review_date               review_id review_language  \
# 0  ['9', '14', '2018']  dIaFxaGjQwrAAnKm57Se_w              en
# 1  ['5', '15', '2018']  ruTcyqV1E7UlOZ4I2ZLJHQ              en
#
#                                                 text        ufc  \
# 0  Cute location, however it is quite small. The ...  [0, 0, 0]
# 1  Pulled pork burger, salmon and cream cheese ba...  [1, 0, 0]
#
#                   user_id             user_loc  vote_count  Updated  Year  \
# 0  0HVBYtQOhI8sVc7n4bZxCw  Mississauga, Canada         0.0    False  2018
# 1  Qr5QmYRZHrh7zaqjYw63AQ      Toronto, Canada         1.0    False  2018
#
#    Day  Month  level_0  index  Unnamed: 0_y                    alias  \
# 0   14      9     1902   8511          8511  black-goat-cafe-toronto
# 1   15      5     1902   8511          8511  black-goat-cafe-toronto
#
#                                       coordinates    display_phone  \
# 0  {'latitude': 43.59672, 'longitude': -79.52254}  +1 416-792-7200
# 1  {'latitude': 43.59672, 'longitude': -79.52254}  +1 416-792-7200
#
#      distance                                          image_url  is_closed  \
# 0  5179.05848  https://s3-media2.fl.yelpcdn.com/bphoto/QWleI6...      False
# 1  5179.05848  https://s3-media2.fl.yelpcdn.com/bphoto/QWleI6...      False
#
#                                             location             name  \
# 0  {'address1': '3261 Lake Shore Boulevard W', 'a...  Black Goat Cafe
# 1  {'address1': '3261 Lake Shore Boulevard W', 'a...  Black Goat Cafe
#
#           phone price  business_stars  review_count_y transactions  \
# 0  1.416793e+10     $             3.5              17           []
# 1  1.416793e+10     $             3.5              17           []
#
#                                                  url  latitude  longitude  \
# 0  https://www.yelp.com/biz/black-goat-cafe-toron...  43.59672  -79.52254
# 1  https://www.yelp.com/biz/black-goat-cafe-toron...  43.59672  -79.52254
#
#          date categories
# 0  2018-09-14      Cafes
# 1  2018-05-15      Cafes

# %%
print('#of reviews:', len(df))
# Out:
# #of reviews: 402927

# %%
df_business_clean.head(2)
# Out:
#    level_0  index  Unnamed: 0                    alias  \
# 0        0      0           0    the-ossington-toronto
# 1        1      1           1  life-is-sweet-toronto-3
#
#                                           categories  \
# 0      [{'alias': 'divebars', 'title': 'Dive Bars'}]
# 1  [{'alias': 'desserts', 'title': 'Desserts'}, {...
#
#                                          coordinates    display_phone  \
# 0      {'latitude': 43.6456, 'longitude': -79.41903}  +1 416-850-0161
# 1  {'latitude': 43.67212500034, 'longitude': -79....  +1 416-698-0555
#
#       distance             business_id  \
# 0  4831.221092  KUdj08tVC3tvIT0rM6V8uQ
# 1  1716.906703  rnjFHvb1I-KlnGvv_o_Zxg
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/dEQPAb...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/s11QxZ...      False
#
#                                             location           name  \
# 0  {'address1': '61 Ossington Avenue', 'address2'...  The Ossington
# 1  {'address1': '2345 Queen Street E', 'address2'...  Life is Sweet
#
#           phone price  rating  review_count transactions  \
# 0  1.416850e+10    $$     3.0            46           []
# 1  1.416698e+10    $$     4.0            10           []
#
#                                                  url        latitude  \
# 0  https://www.yelp.com/biz/the-ossington-toronto...         43.6456
# 1  https://www.yelp.com/biz/life-is-sweet-toronto...  43.67212500034
#
#          longitude
# 0        -79.41903
# 1  -79.28946080056

# %%
set(df['categories'])
# Out:
# {'Argentine',
#  'American (Traditional)',
#  'Bakeries, Desserts, Coffee & Tea',
#  'Canadian (New), Seafood, Vegan',
#  'Cocktail Bars',
#  'Creperies, Cafes, Desserts',
#  'Cajun/Creole, Seafood, Asian Fusion',
#  'Vietnamese, Fast Food',
#  'American (Traditional), Sports Bars, Chicken Wings',
#  'Chinese, Halal',
#  'Barbeque, Mexican, Pubs',
#  'Seafood, Steakhouses',
#  'Specialty Food, Caribbean',
#  'Mexican',
#  'Breakfast & Brunch, Bakeries, Bagels',
#  'Bars, Steakhouses',
#  'Indian, Bangladeshi',
#  'Latin American, Peruvian',
#  'Waffles, Ice Cream & Frozen Yogurt, Patisserie/Cake Shop',
#  'Mediterranean, Modern European',
#  'Music Venues, Cafes',
#  'French, Bistros',
#  'French, Wine Bars, Cocktail Bars',
#  'Chinese, Buffets',
#  'Salad, Juice Bars & Smoothies, Soup',
#  'Desserts, Filipino',
#  'Lounges, Dance Clubs',
#  'Thai, Asian Fusion',
#  'Thai, Vietnamese',
#  'Middle Eastern, Salad, Soup',
#  'Cocktail Bars, Gastropubs, Lounges',
#  'Dance Clubs, Venues & Event Spaces, Lounges',
#  'Coffee & Tea, Turkish, Internet Cafes',
#  'Vietnamese, Bakeries, Sandwiches',
#  'Food Delivery Services, Chinese',
#  'Indian, Chinese',
#  'Comfort Food, Breakfast & Brunch, Sandwiches',
#  'Sandwiches, Breakfast & Brunch, Delis',
#  'Bagels',
#  'Chinese, Asian Fusion',
#  'Japanese, Food Court, Fast Food',
#  'Chicken Wings, Desserts, Sandwiches',
#  'Greek, Turkish',
#  'Pool Halls, Sports Bars, American (Traditional)',
#  'Caterers, Sushi Bars',
#  'Canadian (New), Cafes, Breakfast & Brunch',
#  'Korean, Asian Fusion, Hot Pot',
#  'Italian, Brasseries, Cocktail Bars',
#  'Cafes, Asian Fusion, Cocktail Bars',
#  'Desserts, Chinese, Asian Fusion',
#  'French, Coffee & Tea, Breakfast & Brunch',
#  'Middle Eastern, Vegan, Vegetarian',
#  'Korean, Chinese',
#  'Fast Food, Asian Fusion',
#  'Modern European',
#  'Specialty Food, Modern European',
#  'Pizza, Greek, Breakfast & Brunch',
#  'Chinese, Seafood, Chicken Wings',
#  'Vietnamese, Chinese',
#  'Delis, Diners',
#  'Portuguese, Steakhouses, Chicken Shop',
#  'Vietnamese, Malaysian, Thai',
#  'Middle Eastern, Mediterranean, Sandwiches',
#  'Desserts, Coffee & Tea, Chinese',
#  'Japanese, Sushi Bars, Buffets',
#  'Food Stands, Waffles',
#  'Diners, Greek',
#  'Breakfast & Brunch, Burgers',
#  'Salad, Mediterranean, Sandwiches',
#  'Salad, Gluten-Free, Juice Bars & Smoothies',
#  'Barbeque, Breakfast & Brunch, Bars',
#  'Tex-Mex, Steakhouses, Bars',
#  'Taiwanese, Japanese',
#  'Middle Eastern, Halal, Falafel',
#  'Delis, Coffee & Tea, Sandwiches',
#  'Specialty Food, Bakeries',
#  'Salad, Cafes, Sandwiches',
#  'Desserts, American (Traditional), Salad',
#  'Italian, Pizza, Sandwiches',
#  'Polish, Seafood, Sandwiches',
#  'Venues & Event Spaces, Coffee Roasteries',
#  'Caterers, Barbeque, Portuguese',
#  'Greek, Coffee & Tea, Breakfast & Brunch',
#  'Pakistani, Asian Fusion',
#  'Pizza, Turkish',
#  'Halal, Middle Eastern',
#  'Seafood, Cajun/Creole',
#  'Caribbean, Hakka',
#  'Canadian (New), Bars',
#  'Barbeque, Food Court',
#  'Salad, Vegan, Vegetarian',
#  'Breakfast & Brunch, Diners, Canadian (New)',
#  'Bakeries, Desserts, Donuts',
#  'Falafel, Kosher, Middle Eastern',
#  'Fast Food, Mexican',
#  'Mediterranean, Kebab',
#  'Mexican, Salad, Korean',
#  'Fish & Chips, Soup, Sandwiches',
#  'Salad, Soup, Ice Cream & Frozen Yogurt',
#  'Coffee & Tea, Donuts',
#  'Cocktail Bars, Comfort Food',
#  'Desserts, Ice Cream & Frozen Yogurt',
#  'Thai, Fast Food',
#  'Ice Cream & Frozen Yogurt, Coffee & Tea',
#  'Cafes, Bars',
#  'Coffee & Tea, Breakfast & Brunch, Cafes',
#  'Chocolatiers & Shops, Ice Cream & Frozen Yogurt',
#  'Mediterranean, Greek',
#  'Canadian (New), Vietnamese',
#  'Canadian (New), Barbeque',
#  'Chicken Wings, Canadian (New), Sports Bars',
#  'Dim Sum, Asian Fusion',
#  'French, Seafood, Bistros',
#  'Greek, Canadian (New)',
#  'Lebanese, Mediterranean',
#  'Canadian (New), Italian, Breakfast & Brunch',
#  'Pubs, Breakfast & Brunch, American (Traditional)',
#  'Fast Food, Filipino, Canadian (New)',
#  'Barbeque, Bars, American (Traditional)',
#  'Mediterranean, Cocktail Bars',
#  'Bagels, Coffee & Tea',
#  'Breakfast & Brunch, Desserts, Creperies',
#  'Italian',
#  'Middle Eastern, Arabian, Falafel',
#  'Coffee & Tea, Japanese',
#  'Desserts, Italian, Cafes',
#  'Chicken Wings, Chicken Shop, Fast Food',
#  'Chicken Wings, Pizza, Sandwiches',
#  'Russian, Diners',
#  'Creperies, Delis',
#  'Mediterranean, Sandwiches',
#  'Fast Food, Burgers',
#  'Poke, Hawaiian',
#  'French, Wine Bars',
#  'Italian, Fast Food',
#  'Falafel, Salad, Sandwiches',
#  'Dim Sum, Sushi Bars',
#  'Food Trucks, Vegan',
#  'Ice Cream & Frozen Yogurt, Desserts, Burgers',
#  'Pubs, American (Traditional)',
#  'Italian, Tapas/Small Plates',
#  'Coffee & Tea, Juice Bars & Smoothies, Tea Rooms',
#  'Mexican, Fast Food',
#  'Breakfast & Brunch, Bakeries, Chinese',
#  'Salad, American (Traditional), Vegetarian',
#  'Coffee & Tea, Sandwiches, Himalayan/Nepalese',
#  'Delis, Sandwiches, Vegetarian',
#  'Bakeries, Coffee & Tea, Desserts',
#  'Delis',
#  'Wine Bars',
#  'Diners, Cafes',
#  'Venues & Event Spaces, Dim Sum, Seafood',
#  'Chicken Shop, Waffles, Burgers',
#  'Donuts, Bakeries',
#  'Vietnamese',
#  'Food Trucks, Indian',
#  'Hawaiian, Seafood, Poke',
#  'Delis, Coffee & Tea',
#  'Bars, American (Traditional)',
#  'Salad, Juice Bars & Smoothies, Burgers',
#  'Bakeries, Custom Cakes, Cafes',
#  'Salad, Mediterranean, Acai Bowls',
#  'Cajun/Creole, Southern, Soul Food',
#  'Barbeque, Burgers, Sandwiches',
#  'Canadian (New), Burgers, Sandwiches',
#  'Pakistani',
#  'Japanese, Mexican, Sushi Bars',
#  'Bars, Sandwiches',
#  'Social Clubs, Lounges',
#  'Fast Food, Burgers, American (Traditional)',
#  'Cafes, Desserts, French',
#  'Canadian (New), Tapas/Small Plates',
#  'Wine Bars, Canadian (New)',
#  'Pool Halls, Music Venues, Canadian (New)',
#  'Chocolatiers & Shops, Desserts, Bakeries',
#  'Delis, Breakfast & Brunch',
#  'Patisserie/Cake Shop, Custom Cakes, Bakeries',
#  'Pakistani, Barbeque, Seafood',
#  'Japanese, Imported Food',
#  'Cafes, Ice Cream & Frozen Yogurt, Vietnamese',
#  'Coffee & Tea, Desserts, Breakfast & Brunch',
#  'Music Venues, Dive Bars',
#  'Barbeque, Food Trucks',
#  'Coffee & Tea, Ice Cream & Frozen Yogurt',
#  'Bars, Italian, Breakfast & Brunch',
#  'Desserts, Halal',
#  'Sandwiches, Coffee & Tea',
#  'Lounges, Breakfast & Brunch, Canadian (New)',
#  'Desserts, Custom Cakes',
#  'Gastropubs',
#  'Fast Food, Sandwiches, Chicken Wings',
#  'Desserts, Bubble Tea, Hong Kong Style Cafe',
#  'Seafood, Chicken Wings, Pizza',
#  'Bakeries, Desserts, Patisserie/Cake Shop',
#  'Canadian (New), Sports Bars, Burgers',
#  'Cafes, Desserts',
#  'Wine Bars, Cafes, Tapas Bars',
#  'Food Court, Filipino',
#  'Indian, Venues & Event Spaces, Buffets',
#  'Indian, Pakistani, Cocktail Bars',
#  'Chocolatiers & Shops, Coffee & Tea',
#  'Breweries, Pubs',
#  'Pubs, Venues & Event Spaces',
#  'Chinese, Indian',
#  'Hong Kong Style Cafe, Food Court',
#  'American (Traditional), Breakfast & Brunch, Diners',
#  'Desserts, Macarons, Patisserie/Cake Shop',
#  'Bakeries, Italian, Desserts',
#  'Health Markets, Gluten-Free, Vegetarian',
#  'Delis, Creperies',
#  'Greek, Canadian (New), Breakfast & Brunch',
#  'Ice Cream & Frozen Yogurt, Fast Food',
#  'Seafood, Steakhouses, Cocktail Bars',
#  'Canadian (New), Diners',
#  'Salad, Pizza, Sandwiches',
#  'Bars, Comfort Food',
#  'Canadian (New), Burgers, Chicken Wings',
#  'Fast Food, Ice Cream & Frozen Yogurt',
#  'Sandwiches, Vietnamese',
#  'Salad, Greek',
#  'Diners, Breakfast & Brunch, Canadian (New)',
#  'Ice Cream & Frozen Yogurt, Donuts',
#  'Canadian (New), Steakhouses, Comfort Food',
#  'Sandwiches, Cannabis Clinics, Coffee & Tea',
#  'Breakfast & Brunch, Bakeries, Coffee & Tea',
#  'Burgers',
#  'Cocktail Bars, Canadian (New), Breakfast & Brunch',
#  'Bakeries, Cafes, Delis',
#  'Desserts, Vegan, Bakeries',
#  'Butcher, Cheese Shops',
#  'Halal, Pakistani',
#  'Italian, Mediterranean',
#  'Salad, Sandwiches, Health Markets',
#  'Delis, Bakeries',
#  'Bistros, American (Traditional)',
#  'Kebab, Afghan',
#  'Imported Food',
#  'Fruits & Veggies, Juice Bars & Smoothies',
#  'American (Traditional), Chicken Wings, Sports Bars',
#  'Cocktail Bars, Sports Clubs, American (Traditional)',
#  'Coffee & Tea, Italian, Cafes',
#  'Bakeries, Filipino',
#  'Chicken Shop, Seafood',
#  'Bars, Mediterranean, Modern European',
#  'Caribbean, Chinese',
#  'Pizza, Kosher',
#  'Thai, Seafood, Noodles',
#  'Desserts, Coffee & Tea, Bakeries',
#  'Pizza, Pubs, Beer Bar',
#  'Hawaiian, Sushi Bars, Poke',
#  'Southern, Mediterranean, Modern European',
#  'Bakeries, Chocolatiers & Shops, Macarons',
#  'Middle Eastern, Mediterranean',
#  'Bakeries, Pizza',
#  'Desserts, Breakfast & Brunch, Bakeries',
#  'Breakfast & Brunch, American (Traditional), Diners',
#  'Beer Bar, Canadian (New), Cocktail Bars',
#  'Bakeries, Italian, Ice Cream & Frozen Yogurt',
#  'Hookah Bars, Mediterranean, Lounges',
#  'Breakfast & Brunch, Chocolatiers & Shops',
#  'Cheese Shops, Bakeries',
#  'Fast Food, Poutineries',
#  'Burgers, Sandwiches, Salad',
#  'Cafes, Social Clubs',
#  'Wine Bars, Venues & Event Spaces, Argentine',
#  'Steakhouses, Sports Bars, Tex-Mex',
#  'Coffee & Tea, Bakeries, Bagels',
#  'Greek, Fast Food',
#  'Cafes, Delis, Bakeries',
#  'Desserts, Bakeries, Macarons',
#  'Desserts, Korean, Fish & Chips',
#  'Chinese, Peruvian',
#  'Middle Eastern, Vegetarian, Juice Bars & Smoothies',
#  'Bars, Dance Clubs, Music Venues',
#  'Seafood, Greek, Mediterranean',
#  'Mediterranean, American (Traditional)',
#  'Indian, Pizza',
#  'Canadian (New), Wine Bars',
#  'Bars, Comfort Food, Canadian (New)',
#  'Desserts, Specialty Food, Chinese',
#  'Portuguese, Barbeque, Seafood',
#  'Breakfast & Brunch, Comfort Food',
#  'Sushi Bars, Japanese, Buffets',
#  'Dim Sum, Seafood, Noodles',
#  'Caribbean, Seafood, Imported Food',
#  'Taiwanese, Desserts',
#  'Specialty Food, Caterers, Cafes',
#  'Thai, Vietnamese, Juice Bars & Smoothies',
#  'Irish Pub, Gastropubs',
#  'Greek, Salad, Sandwiches',
#  'Burgers, Diners',
#  'Burgers, Sports Bars, Canadian (New)',
#  'Sports Bars, Venues & Event Spaces',
#  'Donuts, Breakfast & Brunch',
#  'Hawaiian, Juice Bars & Smoothies',
#  'Coffee & Tea, Bakeries, Donuts',
#  'Cafes, Breakfast & Brunch, Coffee & Tea',
#  'Street Vendors, Food Stands',
#  'Sandwiches, Breakfast & Brunch, Delicatessen',
#  'Malaysian, Chinese, Asian Fusion',
#  'Seafood, American (Traditional), Bars',
#  'Pizza, Burgers, Fish & Chips',
#  'Vegan, Salad, Vegetarian',
#  'Desserts, Coffee & Tea, Juice Bars & Smoothies',
#  'Coffee & Tea, Bakeries, Ice Cream & Frozen Yogurt',
#  'Portuguese, Brazilian, Barbeque',
#  'Caribbean, Lounges, Karaoke',
#  'Italian, Seafood, Fish & Chips',
#  'Japanese, Seafood Markets',
#  'Food Trucks, Street Vendors, Imported Food',
#  'Lounges, International, Caribbean',
#  'Coffee & Tea, Hawaiian, Juice Bars & Smoothies',
#  'Vietnamese, Thai',
#  'Ice Cream & Frozen Yogurt, Juice Bars & Smoothies',
#  'Juice Bars & Smoothies, Live/Raw Food, Health Markets',
#  'Hookah Bars, Cafes, Mediterranean',
#  'Filipino, Desserts, Seafood',
#  'Seafood, Portuguese',
#  'Specialty Food, Organic Stores',
#  'Donuts, Coffee & Tea',
#  'Chinese, Fast Food',
#  'Thai, Food Court',
#  'Steakhouses, Lounges',
#  'Ramen, Cocktail Bars',
#  'Lounges, Italian, Caribbean',
#  'Lounges, Pubs',
#  'African, Portuguese, Chicken Wings',
#  'Indian, Breakfast & Brunch, Buffets',
#  'Steakhouses, Cocktail Bars, Lounges',
#  'Bars, Canadian (New), Comfort Food',
#  'Desserts, Asian Fusion',
#  'Greek, Breakfast & Brunch, Sandwiches',
#  'Seafood, Dim Sum, Barbeque',
#  'Mediterranean, Steakhouses',
#  'Fish & Chips, Seafood',
#  'Falafel',
#  'Chinese, Halal, Turkish',
#  'Hungarian',
#  'Salad, Juice Bars & Smoothies, Health Markets',
#  'Tea Rooms, Vegetarian',
#  'Breakfast & Brunch, British',
#  'Pakistani, Fast Food',
#  'Korean, Noodles, Hot Pot',
#  'Bakeries, Patisserie/Cake Shop',
#  'Comfort Food, Polish, Canadian (New)',
#  'Delis, Ice Cream & Frozen Yogurt',
#  'Halal, Falafel, Fast Food',
#  'Pubs, Breakfast & Brunch, Music Venues',
#  'Coffee & Tea, Taiwanese',
#  'Karaoke, Lounges',
#  'Cooking Classes, Cafes',
#  'Chinese, Breakfast & Brunch, Asian Fusion',
#  'Food Stands',
#  'Pizza, Italian, Salad',
#  'Soup, Chinese',
#  'Caribbean, Chinese, Lounges',
#  'Comfort Food, Coffee & Tea, Bars',
#  'Live/Raw Food, Juice Bars & Smoothies, Salad',
#  'Canadian (New), Breakfast & Brunch, Greek',
#  'Sandwiches, Cheesesteaks',
#  'Donuts, Food Trucks',
#  'International, Cocktail Bars, Music Venues',
#  'Coffee & Tea, Desserts, Juice Bars & Smoothies',
#  'Donuts, Coffee & Tea, Sandwiches',
#  'Japanese, Sushi Bars, Seafood',
#  'Lounges, Canadian (New)',
#  'Tapas/Small Plates, Bars',
#  'Italian, American (Traditional), Pizza',
#  'Chinese, Cafes, Breakfast & Brunch',
#  'Burgers, Fast Food, Chicken Wings',
#  'Sports Bars, Karaoke, Music Venues',
#  'Karaoke, Seafood, Live/Raw Food',
#  'Bakeries, Cafes',
#  'Desserts, Chinese, Coffee & Tea',
#  'Latin American, Music Venues',
#  'Italian, Wine Bars, Pizza',
#  'Caribbean, Bakeries',
#  'Modern European, Bars, Canadian (New)',
#  'Indian, Wine Bars',
#  'Steakhouses, African',
#  'Breakfast & Brunch, Dive Bars',
#  'Cajun/Creole, Seafood',
#  'Canadian (New), Wine Bars, Breakfast & Brunch',
#  'Ramen, Sushi Bars',
#  'American (Traditional), Canadian (New), Sports Bars',
#  'Coffee & Tea, Bagels, Donuts',
#  'Pubs, Burgers',
#  'Latin American, Food Stands',
#  'Indian, Pakistani, Bangladeshi',
#  'Fast Food, Chicken Wings, Chicken Shop',
#  'Pizza, Food Delivery Services',
#  'Pizza, Kosher, Sandwiches',
#  'Japanese, Korean',
#  'African, Burgers, Sandwiches',
#  'Breakfast & Brunch, Vegetarian, Sandwiches',
#  'Chicken Shop, Fast Food, Chicken Wings',
#  'Indian, Halal, Pakistani',
#  'Juice Bars & Smoothies, Ice Cream & Frozen Yogurt',
#  'Vegan, Vegetarian, Juice Bars & Smoothies',
#  'Lounges, Greek, Mediterranean',
#  'Sandwiches, Caterers',
#  'Cocktail Bars, Cafes',
#  'Wine Bars, Italian, Mediterranean',
#  'Mediterranean, Turkish, Halal',
#  'Seafood, Fish & Chips, Sandwiches',
#  'Himalayan/Nepalese, Cafes',
#  'Wine Bars, Cafes, Coffee & Tea',
#  'Pubs, Breakfast & Brunch, Burgers',
#  'Juice Bars & Smoothies, Health Markets',
#  'Sushi Bars, Salad, Soup',
#  'Soup',
#  'Filipino, Breakfast & Brunch, Burgers',
#  'Vegetarian, Indian, Desserts',
#  'Coffee & Tea, Cafes, Breakfast & Brunch',
#  'Coffee & Tea, Tea Rooms, Waffles',
#  'Pubs',
#  'Lounges, Dance Clubs, Cocktail Bars',
#  'Caribbean, Indian, Canadian (New)',
#  'Sandwiches, Pizza, Salad',
#  'Middle Eastern, Halal, Afghan',
#  'Gluten-Free, Vegetarian, Vegan',
#  'Mexican, Vegan, Fast Food',
#  'French, Bistros, Diners',
#  'Hookah Bars, American (Traditional)',
#  'Chinese, Hot Pot, Noodles',
#  'Pizza, Italian, Chicken Wings',
#  'Desserts, Coffee & Tea, Tea Rooms',
#  'Sushi Bars, Ramen',
#  'Fast Food, Diners, Chicken Wings',
#  'Hot Pot, Soup',
#  'Chinese, Thai, Indian',
#  'Salvadoran, Pop-up Shops',
#  'Mediterranean, Food',
#  'Italian, Gluten-Free',
#  'Bars, Barbeque',
#  'Mediterranean, Pizza, Turkish',
#  'Waffles, Chicken Shop',
#  'Indian, Kebab',
#  'Vegetarian, Indian, Fast Food',
#  'Pool Halls, Sports Bars, Canadian (New)',
#  'Seafood, Desserts, Coffee & Tea',
#  'Polish, Modern European, Cafes',
#  'Gluten-Free, Vegetarian, Health Markets',
#  'Portuguese, South African',
#  'Pubs, Comfort Food',
#  'Burgers, Greek, Breakfast & Brunch',
#  'Caribbean, African, Lounges',
#  'Delis, Breakfast & Brunch, Bagels',
#  'Creperies, Japanese, Chinese',
#  'Venues & Event Spaces, Lounges, Dance Clubs',
#  'Chicken Shop, Comfort Food, Sandwiches',
#  'Breakfast & Brunch, Coffee & Tea, Japanese',
#  'Fruits & Veggies, Imported Food',
#  'Indian, Mediterranean, Halal',
#  'Pubs, Seafood, Canadian (New)',
#  'American (Traditional), Comfort Food',
#  'Chicken Wings, Burgers, Pubs',
#  'Steakhouses, Kosher, Bistros',
#  'Halal, Bangladeshi',
#  'Japanese, Lounges, Sushi Bars',
#  'Chinese, Korean',
#  'Chicken Wings, Seafood, Fast Food',
#  'Asian Fusion, Gluten-Free',
#  'Bakeries, Desserts',
#  'Cheese Shops, Meat Shops',
#  'Italian, Breakfast & Brunch, French',
#  'Chinese, Tapas/Small Plates',
#  'Lounges, Japanese, Tapas Bars',
#  'Canadian (New), Pubs',
#  'Desserts, Italian, Pizza',
#  'Mediterranean, Diners',
#  'Karaoke, Filipino',
#  'Japanese, Coffee & Tea',
#  'Fast Food, Food Trucks',
#  'Gluten-Free, Patisserie/Cake Shop, Bakeries',
#  'Cafes, Fast Food',
#  'Venues & Event Spaces, Lounges',
#  'Fast Food, Hot Dogs, Burgers',
#  'Bars, Canadian (New), Breakfast & Brunch',
#  'Korean, Pubs',
#  'Lounges, Breakfast & Brunch, Comfort Food',
#  'Seafood, Dim Sum',
#  'Lebanese, Bakeries',
#  'Restaurants, Wine Bars',
#  'Coffee & Tea, Bagels',
#  'Bakeries, French',
#  'Russian, Ukrainian',
#  'Specialty Food, Asian Fusion, Japanese',
#  'Coffee & Tea, Juice Bars & Smoothies, Sandwiches',
#  'Delis, Burgers, Sandwiches',
#  'Juice Bars & Smoothies, Coffee & Tea, Health Markets',
#  'Juice Bars & Smoothies, Salad',
#  'Steakhouses, Brazilian, Latin American',
#  'Comfort Food, Vegan, Burgers',
#  'Food Stands, Street Vendors',
#  'Bakeries, Cafes, Sports Bars',
#  'Thai, Laotian',
#  'Vietnamese, Vegan, Chinese',
#  'Middle Eastern, Persian/Iranian',
#  'Vegetarian, Dim Sum',
#  'Vegan, Vegetarian',
#  'Modern European, Gluten-Free, Tapas/Small Plates',
#  'Seafood, Thai',
#  'Halal, Arabian, Middle Eastern',
#  'Latin American, Fast Food',
#  'Pubs, Comfort Food, Breakfast & Brunch',
#  'Meat Shops, Delis',
#  'Tex-Mex, Street Vendors, Cocktail Bars',
#  'Juice Bars & Smoothies, Coffee & Tea',
#  'Mexican, Cocktail Bars',
#  'Bakeries, Chinese',
#  'Sandwiches, Kebab, Mexican',
#  'Mexican, Asian Fusion, Vietnamese',
#  'Sandwiches, Delis',
#  'Vegan, Vegetarian, Gluten-Free',
#  'Vegan, Italian',
#  'Mexican, Sandwiches',
#  'Breakfast & Brunch, Bars',
#  'Spanish, Wine Bars, Tapas Bars',
#  'Seafood, Sandwiches, Chicken Wings',
#  'Cideries, Pubs',
#  'Burgers, Greek, Salad',
#  'Breakfast & Brunch, Bars, American (Traditional)',
#  'Bakeries, Coffee & Tea, Organic Stores',
#  'Italian, Bars',
#  'Bakeries, Vegan',
#  'Chinese, Ramen',
#  'Caribbean, Chinese, Bars',
#  'Vegetarian, Vegan, Indian',
#  'Dive Bars, Chinese',
#  'Hong Kong Style Cafe',
#  'Latin American, Fast Food, Comfort Food',
#  'Coffee & Tea, Caterers',
#  'Japanese, Thai, Chinese',
#  'Vietnamese, Noodles',
#  'Mediterranean, Spanish, Breakfast & Brunch',
#  'Burmese, Asian Fusion',
#  'Thai, Vegan',
#  'Italian, Lounges',
#  'Chinese, Seafood, Soup',
#  'British, Pubs',
#  'Halal, Cafes, Pizza',
#  'Indian, Halal, Pizza',
#  'Bars, Cafes',
#  'Diners, Breakfast & Brunch, Halal',
#  'Chicken Wings, Chicken Shop',
#  'Japanese, Sushi Bars, Tapas Bars',
#  'Sports Bars, Lounges, Canadian (New)',
#  'Canadian (New), Steakhouses, Lounges',
#  'German',
#  'Japanese, Noodles',
#  'Salad, Sandwiches',
#  'Sandwiches, Pizza, Italian',
#  'Ukrainian',
#  'Ramen, Asian Fusion',
#  'Bars, Chicken Wings',
#  'Sandwiches, Salad, Juice Bars & Smoothies',
#  'Festivals',
#  'Taiwanese',
#  'Breakfast & Brunch, Bagels',
#  'Japanese, Tapas/Small Plates',
#  'Chicken Wings, Barbeque',
#  'Canadian (New), Jazz & Blues, Seafood',
#  'Japanese, Sushi Bars, Asian Fusion',
#  'Russian',
#  'Vegetarian, Chinese',
#  'Modern European, Bars',
#  'Caribbean, Fast Food, Diners',
#  'Middle Eastern, Sandwiches, Mediterranean',
#  'Bakeries, Desserts, Macarons',
#  'Cafes, Wine Bars, Beer Bar',
#  'Cafes, Italian, Sandwiches',
#  'Cocktail Bars, Canadian (New)',
#  'Thai, Filipino',
#  'Bars, Greek, Breakfast & Brunch',
#  'Asian Fusion, Italian',
#  'Dive Bars, Dance Clubs',
#  'Syrian, Middle Eastern, Arabian',
#  'Indian, Desserts, Pakistani',
#  'Vietnamese, Thai, Gluten-Free',
#  'Sandwiches, Coffee & Tea, Breakfast & Brunch',
#  'French, Cafes',
#  'Middle Eastern, Mediterranean, Halal',
#  'Barbeque',
#  'Donairs, Imported Food',
#  'Pubs, Bistros, Cafes',
#  'Taiwanese, Asian Fusion',
#  'Chicken Wings, Sports Bars, Burgers',
#  'Fast Food, Pakistani',
#  'Afghan, Middle Eastern, Persian/Iranian',
#  'Bangladeshi',
#  'Delis, Specialty Food',
#  'Bakeries, Bars',
#  'Breakfast & Brunch, Diners, Coffee & Tea',
#  'American (Traditional), Fast Food, Burgers',
#  'American (Traditional), Burgers',
#  'Desserts, Bakeries, Patisserie/Cake Shop',
#  'Breakfast & Brunch, Juice Bars & Smoothies',
#  'Vegetarian, Sandwiches',
#  'Tapas Bars, Korean, Canadian (New)',
#  'Japanese, Barbeque',
#  'Thai, Vegan, Vegetarian',
#  'Internet Cafes',
#  'Karaoke, Lounges, Asian Fusion',
#  'Bars, Comfort Food, American (Traditional)',
#  'Coffee & Tea, Asian Fusion, Taiwanese',
#  'Asian Fusion, Vietnamese',
#  'Indian, Seafood, Hot Dogs',
#  'Venezuelan, Gluten-Free, Sandwiches',
#  'Singaporean',
#  'Seafood, Hakka',
#  'Pubs, Burgers, American (Traditional)',
#  'Cajun/Creole, Fast Food, Chicken Wings',
#  'Thai, Asian Fusion, Sushi Bars',
#  'Spanish, Tapas/Small Plates, Cocktail Bars',
#  'Barbeque, Chinese',
#  'Cafes, Breakfast & Brunch',
#  'Mexican, Cocktail Bars, Latin American',
#  'Asian Fusion, Hakka',
#  'Asian Fusion, Korean, Sushi Bars',
#  'Breakfast & Brunch, Mediterranean',
#  'Coffee & Tea, Cafes, Cocktail Bars',
#  'Peruvian',
#  'Bistros, Beer Bar',
#  'Mediterranean, Turkish, Kebab',
#  'Cajun/Creole, Chicken Wings',
#  'Breweries, Gastropubs, Pizza',
#  'Cafes, Food Stands',
#  'Fast Food, Greek',
#  'Korean, Imported Food',
#  'Smokehouse, Barbeque, Italian',
#  'Salad, Breakfast & Brunch, Soup',
#  'Chocolatiers & Shops, Bakeries, Desserts',
#  'Chinese, Soup',
#  'Desserts, Donuts, Bakeries',
#  'Caribbean, Chicken Shop',
#  'Pubs, Music Venues, Sports Bars',
#  'Japanese, Buffets',
#  'Food Delivery Services, Dim Sum',
#  'Cafes, Bakeries',
#  'American (Traditional), Bars, Breakfast & Brunch',
#  'Italian, Seafood',
#  'Chinese, Japanese',
#  'Sandwiches, Cafes, Coffee & Tea',
#  'Barbeque, Dim Sum',
#  'Thai, Pan Asian, Chinese',
#  'Desserts, Tea Rooms, Ice Cream & Frozen Yogurt',
#  'American (Traditional), Breakfast & Brunch, Burgers',
#  'Salvadoran',
#  'Wine Bars, Steakhouses, Desserts',
#  'Steakhouses, Bars, Seafood',
#  'Thai, Chinese, Japanese',
#  'Sushi Bars, Japanese, Thai',
#  'Seafood, Cajun/Creole, Steakhouses',
#  'Argentine, Italian, Bars',
#  'Pizza, Sandwiches',
#  'Dim Sum, Thai, Asian Fusion',
#  'Chinese, Indian, Seafood',
#  'Bakeries, Delis',
#  'Middle Eastern, Food Court, Imported Food',
#  'Cafes, Coffee & Tea, Bakeries',
#  'Coffee & Tea, Tea Rooms, Chinese',
#  'Meat Shops, Hot Dogs',
#  'Cheese Shops, Delicatessen',
#  'African, Barbeque',
#  'Latin American, Bakeries, Coffee & Tea',
#  'Pubs, Sports Bars, Irish',
#  'Chinese, Fast Food, Asian Fusion',
#  'Tea Rooms, Ice Cream & Frozen Yogurt, Desserts',
#  'Dance Clubs, Lounges',
#  'Cheesesteaks, Sandwiches',
#  'Mediterranean, Middle Eastern, Kosher',
#  'Chinese, Hot Pot',
#  'Japanese, Lounges',
#  'Coffee Roasteries, Coffee & Tea, Bakeries',
#  'Brasseries',
#  'Falafel, Lebanese',
#  'Burgers, Chicken Wings, Sandwiches',
#  'Karaoke, Pubs',
#  'Cocktail Bars, Tapas Bars',
#  'Sports Bars, Canadian (New), Pubs',
#  'Specialty Food, Turkish',
#  'Pakistani, Chinese, Indian',
#  'Lounges, Caribbean',
#  'Lounges, Asian Fusion',
#  'Vietnamese, Vegetarian, Gluten-Free',
#  'Food Trucks, Specialty Food',
#  'Imported Food, Vietnamese, Thai',
#  'Hungarian, Bars',
#  'Middle Eastern, Desserts, Sandwiches',
#  'Bars, Canadian (New), Venues & Event Spaces',
#  'Thai, Food Delivery Services',
#  'Vegetarian, Indian, Vegan',
#  'Delis, Sandwiches',
#  'Wine Bars, Beer Bar',
#  'Sandwiches, Comfort Food, Breakfast & Brunch',
#  'Sushi Bars, Asian Fusion',
#  'Italian, Pizza, Wine Bars',
#  'Kebab, Turkish, Mediterranean',
#  'American (Traditional), Steakhouses',
#  'Champagne Bars, Lounges, Beer Bar',
#  'Japanese, Tapas/Small Plates, Pubs',
#  'Chinese, Noodles, Soup',
#  'Taiwanese, Juice Bars & Smoothies, Japanese',
#  'Korean, Cocktail Bars, Asian Fusion',
#  'Custom Cakes',
#  'Hot Dogs, Latin American, Sandwiches',
#  'Breakfast & Brunch, Cantonese',
#  'Steakhouses, Cocktail Bars, Desserts',
#  'Coffee & Tea, Italian, Breakfast & Brunch',
#  'Caribbean, Lounges, Chinese',
#  'Coffee & Tea, Tea Rooms',
#  'Lounges, Russian',
#  'Greek, Mediterranean, Seafood',
#  'Thai, Noodles, Cocktail Bars',
#  'Ice Cream & Frozen Yogurt, Desserts, Coffee & Tea',
#  'Caribbean, Imported Food',
#  'Bars',
#  'Bakeries, Portuguese, Sandwiches',
#  'Coffee & Tea, Chinese, Nightlife',
#  'Cocktail Bars, Asian Fusion',
#  'Mediterranean, Middle Eastern, Mexican',
#  'Pubs, Canadian (New), Music Venues',
#  'Ice Cream & Frozen Yogurt, Coffee & Tea, Patisserie/Cake Shop',
#  'Coffee & Tea, Salad, Sandwiches',
#  'Sports Bars, Canadian (New)',
#  'Butcher, Sandwiches, Meat Shops',
#  'Japanese, Chinese, Sushi Bars',
#  'Fast Food, Sandwiches',
#  'Canadian (New), Breakfast & Brunch, Sandwiches',
#  'Japanese, Sushi Bars, Salad',
#  'Coffee & Tea, Pubs',
#  'Vietnamese, Imported Food',
#  'Southern, Chicken Shop, Cajun/Creole',
#  'Coffee Roasteries, Cafes, Venues & Event Spaces',
#  'Fish & Chips, Fast Food, Cheesesteaks',
#  'Italian, French, Bistros',
#  'Bakeries, Bagels, Cafes',
#  'Malaysian, Thai',
#  'Salad, Juice Bars & Smoothies',
#  'American (Traditional), Breakfast & Brunch, Fish & Chips',
#  'Sandwiches, Middle Eastern, Coffee & Tea',
#  'Pubs, Comfort Food, Russian',
#  'Street Vendors, Filipino',
#  'Italian, Mediterranean, Breakfast & Brunch',
#  'Chinese, Food Court',
#  'Ramen, Noodles',
#  'Pubs, Gastropubs',
#  'Pizza, Chicken Wings',
#  'Meat Shops, Venues & Event Spaces, Cafes',
#  'Greek, Canadian (New), Bars',
#  'Vegetarian, Vegan, Gluten-Free',
#  'Chicken Shop, Taiwanese',
#  'Soup, Sandwiches, Juice Bars & Smoothies',
#  'Canadian (New), Cafes',
#  'Canadian (New), Tapas/Small Plates, Dance Clubs',
#  'Asian Fusion, Chinese, French',
#  'Juice Bars & Smoothies, Coffee & Tea, Tea Rooms',
#  'Coffee & Tea, Bakeries, Bubble Tea',
#  'Coffee & Tea, Cafes',
#  'Hot Dogs, Burgers, Fast Food',
#  'Burgers, Canadian (New), American (Traditional)',
#  'Bars, Breakfast & Brunch, Canadian (New)',
#  'Barbeque, Tapas Bars, Chinese',
#  'Indian, Italian',
#  'Mediterranean, Turkish, Middle Eastern',
#  'Indian, Halal, Bangladeshi',
#  'Sushi Bars, Japanese',
#  'Delis, Sandwiches, Coffee & Tea',
#  'Italian, Salad, Pizza',
#  'Vietnamese, Thai, Chinese',
#  'Desserts, Salad, Burgers',
#  'Korean, Chicken Shop, Fast Food',
#  'Caribbean, Bars',
#  'Bars, American (Traditional), Pool Halls',
#  'Spanish, Desserts',
#  'Specialty Food, Caterers',
#  'Steakhouses, Venues & Event Spaces',
#  'Burgers, Fast Food',
#  'Brasseries, French',
#  'Delis, Sandwiches, Poutineries',
#  'Himalayan/Nepalese',
#  'Pubs, Salad, Burgers',
#  'Tapas/Small Plates, Italian',
#  'Chinese, Barbeque',
#  'Pan Asian',
#  'Coffee & Tea, Cocktail Bars',
#  'Desserts, Florists',
#  'Specialty Food, Sandwiches',
#  'Delis, Sandwiches, Pizza',
#  'Cafes, Sandwiches, Vegetarian',
#  'Seafood Markets, Kosher',
#  'Lounges, American (Traditional), Cocktail Bars',
#  'Wine Bars, Canadian (New), Italian',
#  'Filipino, Breakfast & Brunch',
#  'Seafood Markets, Meat Shops',
#  'Chicken Wings, Barbeque, Pizza',
#  'Cafes, Lounges',
#  'Filipino, Food',
#  'Chinese, Seafood, Barbeque',
#  'Hungarian, Bistros',
#  'Middle Eastern, Falafel',
#  'Sandwiches, Salad',
#  'Irish, Steakhouses',
#  'Fast Food, Lebanese',
#  'American (Traditional), Lounges, Cocktail Bars',
#  'Vegetarian, Sandwiches, Salad',
#  'Breakfast & Brunch, Diners, Buffets',
#  'Food Delivery Services',
#  'Creperies, Desserts',
#  'Cafes, Persian/Iranian',
#  'Cocktail Bars, Wine Bars',
#  'Bakeries, Gluten-Free, Coffee & Tea',
#  'Fast Food, Comfort Food',
#  'Cafes, French, Mediterranean',
#  'Cuban',
#  'Canadian (New), Burgers',
#  'Latin American, Food Court',
#  'Bars, Indian',
#  'Cafes, Tapas/Small Plates',
#  'Persian/Iranian, Middle Eastern',
#  'Vegetarian, Canadian (New), Comfort Food',
#  'Cafes, Bakeries, Sandwiches',
#  'Salad, Soup, Sandwiches',
#  'Modern European, Bars, Polish',
#  'Thai, Salad, Noodles',
#  'Tex-Mex, Burgers, Steakhouses',
#  'Chicken Wings, American (Traditional)',
#  'Desserts, Coffee & Tea, Breakfast & Brunch',
#  'Seafood, Noodles, Soup',
#  'Tapas Bars, Spanish, Bars',
#  'Pakistani, Halal, Indian',
#  'Belgian, Fast Food',
#  'Pizza, Bars, Chicken Wings',
#  'Sushi Bars, Korean, Japanese',
#  'Social Clubs, Wine Bars',
#  'Tea Rooms, Coffee & Tea, Taiwanese',
#  'Middle Eastern, Bars',
#  'Coffee & Tea, Organic Stores, Juice Bars & Smoothies',
#  'Cocktail Bars, Modern European, Canadian (New)',
#  'Bakeries, Italian, Delicatessen',
#  'Salad, Soup',
#  'Juice Bars & Smoothies, Cafes',
#  'Fast Food, Asian Fusion, Ramen',
#  'Chinese, Vietnamese',
#  'American (Traditional), Barbeque',
#  'Coffee & Tea, Bakeries, Italian',
#  'Gastropubs, Canadian (New)',
#  'Cafes, Wine Bars, Pizza',
#  'Coffee & Tea, Specialty Food',
#  'Pubs, Burgers, Sandwiches',
#  'Spanish, Tapas Bars',
#  'Lounges, Karaoke',
#  'Turkish, Bars',
#  'French, Brasseries',
#  'Cocktail Bars, American (Traditional), Karaoke',
#  'Coffee & Tea, Salad, Breakfast & Brunch',
#  'Champagne Bars, Coffee & Tea',
#  'Mediterranean, Bakeries, Breakfast & Brunch',
#  'Donuts, Bakeries, Bagels',
#  'Hookah Bars, Cafes, Middle Eastern',
#  'Desserts, Taiwanese, Tea Rooms',
#  'American (Traditional), Cocktail Bars, Pubs',
#  'Indian, Halal',
#  'Hot Dogs, Thai, Noodles',
#  'Italian, Breakfast & Brunch, Gastropubs',
#  'Pizza, Greek',
#  'Bars, Breakfast & Brunch, Mexican',
#  'Mediterranean, Caterers, Greek',
#  'Pizza, Italian, Wine Bars',
#  'Caterers, Portuguese',
#  'Canadian (New), American (Traditional)',
#  'Mexican, Tiki Bars',
#  'Live/Raw Food, Vegan',
#  'Fast Food, Do-It-Yourself Food, Canadian (New)',
#  'Chicken Wings, Peruvian, Latin American',
#  'Coffee & Tea, Sandwiches, Wine Bars',
#  'French',
#  'Indian, Malaysian',
#  'Sandwiches, Barbeque, Juice Bars & Smoothies',
#  'Venues & Event Spaces, Mediterranean',
#  'Chinese, Vietnamese, Imported Food',
#  'Fast Food, Mediterranean, Halal',
#  'Creperies, Breakfast & Brunch',
#  'Coffee & Tea, Internet Cafes, Sandwiches',
#  'Portuguese, Burgers, Breakfast & Brunch',
#  'Delis, Breakfast & Brunch, Sandwiches',
#  'Cafes, Tea Rooms',
#  'Fast Food, Chicken Shop, Chicken Wings',
#  'Bangladeshi, Indian',
#  'Breakfast & Brunch, Burgers, Coffee & Tea',
#  'Fast Food, Seafood, Sandwiches',
#  'Gay Bars',
#  'Salad, Dim Sum, Sushi Bars',
#  'Middle Eastern, Falafel, Sandwiches',
#  'Pizza, Burgers, Poutineries',
#  'Chinese, Desserts',
#  'Food Court, Comfort Food, Chinese',
#  'Tapas/Small Plates, Spanish, Tapas Bars',
#  'Japanese, Sushi Bars',
#  'Indian, Desserts',
#  'Caterers, Coffee & Tea, Italian',
#  'Lounges, Venues & Event Spaces',
#  'Halal, Afghan, Middle Eastern',
#  'Middle Eastern, Mexican, Food Trucks',
#  'Lebanese, Halal',
#  'Diners, Breakfast & Brunch',
#  'Lounges, Tapas Bars',
#  'Gastropubs, Asian Fusion, Tapas/Small Plates',
#  'Sandwiches, Coffee & Tea, Donuts',
#  'Chinese, Taiwanese',
#  'Barbeque, Canadian (New)',
#  'Bakeries, Desserts, Delis',
#  'Food Trucks, American (Traditional)',
#  'Sushi Bars, Vegetarian',
#  'Caribbean, Vegan',
#  'Coffee & Tea, Syrian',
#  'Spanish, Tapas/Small Plates, Bars',
#  'Japanese, Chinese, Korean',
#  'Dive Bars, Comfort Food',
#  'Cafes, Chinese',
#  'Cafes, Ethiopian, Desserts',
#  'Sports Bars, Lounges, Asian Fusion',
#  'Waffles, Desserts, Gluten-Free',
#  'Sushi Bars, Pizza, Kosher',
#  'Korean, Chicken Shop',
#  'Filipino, Bakeries',
#  'Hot Dogs, Burgers, Poutineries',
#  'Pakistani, Indian, Middle Eastern',
#  'Music Venues, Pizza',
#  'Do-It-Yourself Food, Specialty Food',
#  'Bagels, Breakfast & Brunch',
#  'Cafes, Kosher, Breakfast & Brunch',
#  'Pizza, American (Traditional)',
#  'Desserts, Patisserie/Cake Shop',
#  'Bistros, Breakfast & Brunch, French',
#  'Lebanese, Pizza',
#  'Singaporean, Thai, Chinese',
#  'American (Traditional), Sandwiches',
#  'Southern, Barbeque',
#  'Sushi Bars, Korean, Asian Fusion',
#  'Vegetarian, American (Traditional)',
#  'Food Trucks, Ice Cream & Frozen Yogurt',
#  'Taiwanese, Tea Rooms',
#  'Korean, Soup, Barbeque',
#  'Steakhouses, Delis, Sandwiches',
#  'Barbeque, Sandwiches, American (Traditional)',
#  'Barbeque, Breakfast & Brunch, Chicken Shop',
#  'Noodles, Chinese',
#  'Portuguese, South African, Chicken Shop',
#  'Poutineries, Delis',
#  'Vegetarian, Vietnamese',
#  'Korean, Dive Bars, Asian Fusion',
#  'Malaysian',
#  'Delis, Sandwiches, Cheese Shops',
#  'Middle Eastern, Indian, Pakistani',
#  'Tea Rooms, Coffee & Tea',
#  'Delis, Cheese Shops, Meat Shops',
#  'Cocktail Bars, Wine Bars, Burgers',
#  'Comfort Food, Mediterranean, Italian',
#  'Korean, Bars',
#  'Middle Eastern, Halal, Desserts',
#  'Macarons',
#  'Barbeque, Southern, Soul Food',
#  'Halal, Chinese',
#  'Breakfast & Brunch, Canadian (New)',
#  'Indian, Vegetarian, Gluten-Free',
#  'Japanese, Thai, Asian Fusion',
#  'Desserts, Cafes, Patisserie/Cake Shop',
#  'Filipino, Asian Fusion, Barbeque',
#  'Thai, Malaysian',
#  'Wine Bars, Tapas/Small Plates',
#  'Chinese, Nightlife',
#  'Creperies, Cafes',
#  'Salad, Fast Food, Sandwiches',
#  'Barbeque, Portuguese',
#  'Lounges, Sushi Bars',
#  'Caribbean, Canadian (New)',
#  'Middle Eastern, Asian Fusion',
#  'Health Markets, Juice Bars & Smoothies',
#  'Russian, Bakeries, Cafes',
#  'Coffee & Tea, Coffee Roasteries',
#  'Sandwiches, Portuguese',
#  'Polish, Ukrainian',
#  'Breakfast & Brunch, Diners',
#  'Chinese, Cambodian',
#  'Breakfast & Brunch, Vietnamese',
#  'Ice Cream & Frozen Yogurt, Patisserie/Cake Shop',
#  'Chinese, Hot Pot, Buffets',
#  'Sports Bars, Asian Fusion',
#  'Desserts, Bangladeshi',
#  'Gluten-Free, Bakeries',
#  'Middle Eastern, Falafel, Halal',
#  'Chinese, Seafood, Vegetarian',
#  'Chicken Wings, Sports Bars, Fast Food',
#  'Food Trucks, Breakfast & Brunch, Canadian (New)',
#  'Hakka, Thai',
#  'Fast Food, Chicken Wings, Seafood',
#  'Nightlife',
#  'Latin American, Spanish, Cocktail Bars',
#  ...}

# %% [markdown]
# ## Extract distinct categories

# %%
final_category = list(df['categories'])

# %%
aList = []
for categories in final_category:
    split_category = [cat.strip() for cat in categories.split(',')]
    for category in split_category:
        aList.append(category)

# %% [markdown]
# # Exporting data

# %%
Export = df.to_json(r'../data/Cleaned_Toronto_Reviews.json', orient='records')

# %%
Export = df_business_clean.to_json(r'../data/Cleaned_Toronto_Business.json', orient='records')

# %% [markdown]
# # Checking the export data

# %%
filename = "..\\data\\Cleaned_Toronto_Business.json"
with open(filename,'r') as f:
        data = f.readlines()
        data = list(map(json.loads, data))
    
data = data[0]
#Get all the data from the dggeata file
df = pd.DataFrame(data)

df.rename(columns={'stars': 'review_stars', 'text': 'review_text', 'cool': 'review_cool',
           'funny': 'review_funny', 'useful': 'review_useful'}, inplace=True)

# %%
df.head(5)
# Out:
#    Unnamed: 0                                 alias             business_id  \
# 0           0                 the-ossington-toronto  KUdj08tVC3tvIT0rM6V8uQ
# 1           1               life-is-sweet-toronto-3  rnjFHvb1I-KlnGvv_o_Zxg
# 2           2                     subway-toronto-51  f8YPC7K4UUTkKatE5ga8Ig
# 3           5             jodies-restaurant-toronto  K5TteBnAfgj18HRnV-Yy4w
# 4          11  the-great-canadian-bagel-ltd-vaughan  ARwwcafc0x5s9wC-Te9yXg
#
#                                                                                   categories  \
# 0                                              [{'alias': 'divebars', 'title': 'Dive Bars'}]
# 1   [{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'bakeries', 'title': 'Bakeries'}]
# 2  [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast F...
# 3  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'diners', 'title': 'Diners'}, {...
# 4                                                   [{'alias': 'bagels', 'title': 'Bagels'}]
#
#                                                       coordinates  \
# 0                   {'latitude': 43.6456, 'longitude': -79.41903}
# 1      {'latitude': 43.67212500034, 'longitude': -79.28946080056}
# 2                  {'latitude': 43.66449, 'longitude': -79.34116}
# 3  {'latitude': 43.6053352355957, 'longitude': -79.5289154052734}
# 4              {'latitude': 43.7928079, 'longitude': -79.5312639}
#
#      display_phone     distance  \
# 0  +1 416-850-0161  4831.221092
# 1  +1 416-698-0555  1716.906703
# 2  +1 416-465-8100  2934.260861
# 3  +1 416-255-5552  4262.777626
# 4  +1 905-760-9955  7595.423171
#
#                                                               image_url  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/dEQPAbThPHKevj07OijSfA/o.jpg
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/s11QxZr-V8-VJHNLQJyvgQ/o.jpg
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/JpxU9FOgghpQQptpdsDDtg/o.jpg
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/GtkSIOchBTNry8WbIiZ7Gg/o.jpg
# 4                                                                  None
#
#    index  is_closed          latitude  level_0  \
# 0      0      False           43.6456        0
# 1      1      False    43.67212500034        1
# 2      2      False          43.66449        2
# 3      5      False  43.6053352355957        3
# 4     11      False        43.7928079        4
#
#                                                                                     location  \
# 0  {'address1': '61 Ossington Avenue', 'address2': '', 'address3': '', 'city': 'Toronto',...
# 1  {'address1': '2345 Queen Street E', 'address2': '', 'address3': '', 'city': 'Toronto',...
# 2  {'address1': '331 Carlaw Avenue', 'address2': 'Unit 103', 'address3': '', 'city': 'Tor...
# 3  {'address1': '331 Horner Avenue', 'address2': '', 'address3': '', 'city': 'Toronto', '...
# 4  {'address1': '3300 Hwy 7', 'address2': 'Suite 101', 'address3': '', 'city': 'Vaughan',...
#
#            longitude                           name         phone price  \
# 0          -79.41903                  The Ossington  1.416850e+10    $$
# 1    -79.28946080056                  Life is Sweet  1.416698e+10    $$
# 2          -79.34116                         Subway  1.416466e+10    $$
# 3  -79.5289154052734             Jodie's Restaurant  1.416256e+10    $$
# 4        -79.5312639  The Great Canadian Bagel, Ltd  1.905761e+10    $$
#
#    rating  review_count transactions  \
# 0     3.0            46           []
# 1     4.0            10           []
# 2     1.5             6           []
# 3     4.5             6           []
# 4     4.0             1           []
#
#                                                                                          url
# 0  https://www.yelp.com/biz/the-ossington-toronto?adjust_creative=uxtIWjm7I33oX3CDHUtQgQ&...
# 1  https://www.yelp.com/biz/life-is-sweet-toronto-3?adjust_creative=9LfdvYfx0rVPnDmG5bc0i...
# 2  https://www.yelp.com/biz/subway-toronto-51?adjust_creative=NeTgDT5IUqTFt2XAEV__OA&utm_...
# 3  https://www.yelp.com/biz/jodies-restaurant-toronto?adjust_creative=uxtIWjm7I33oX3CDHUt...
# 4  https://www.yelp.com/biz/the-great-canadian-bagel-ltd-vaughan?adjust_creative=9LfdvYfx...

# %%
pd.set_option('display.max_columns', None)

# %%
set(df.categories.values)
# Out:
# {"[{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'beerbar', 'title': 'Beer Bar'}]",
#  "[{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'pakistani', 'title': 'Pakistani'}, {'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'seafood', 'title': 'Seafood'}]",
#  "[{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'filipino', 'title': 'Filipino'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'popupshops', 'title': 'Pop-up Shops'}]",
#  "[{'alias': 'personalchefs', 'title': 'Personal Chefs'}, {'alias': 'catering', 'title': 'Caterers'}]",
#  "[{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'turkish', 'title': 'Turkish'}]",
#  "[{'alias': 'french', 'title': 'French'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]",
#  "[{'alias': 'ramen', 'title': 'Ramen'}, {'alias': 'noodles', 'title': 'Noodles'}]",
#  "[{'alias': 'gourmet', 'title': 'Specialty Food'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'japanese', 'title': 'Japanese'}]",
#  "[{'alias': 'creperies', 'title': 'Creperies'}, {'alias': 'tea', 'title': 'Tea Rooms'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'indpak', 'title': 'Indian'}]",
#  "[{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'lounges', 'title': 'Lounges'}, {'alias': 'tapas', 'title': 'Tapas Bars'}]",
#  "[{'alias': 'fishnchips', 'title': 'Fish & Chips'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'dimsum', 'title': 'Dim Sum'}]",
#  "[{'alias': 'pubs', 'title': 'Pubs'}, {'alias': 'bistros', 'title': 'Bistros'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'bartendingschools', 'title': 'Bartending Schools'}]",
#  "[{'alias': 'british', 'title': 'British'}, {'alias': 'gastropubs', 'title': 'Gastropubs'}]",
#  "[{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'pubs', 'title': 'Pubs'}]",
#  "[{'alias': 'bubbletea', 'title': 'Bubble Tea'}, {'alias': 'foodstands', 'title': 'Food Stands'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'gluten_free', 'title': 'Gluten-Free'}]",
#  "[{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'tea', 'title': 'Tea Rooms'}]",
#  "[{'alias': 'tea', 'title': 'Tea Rooms'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}]",
#  "[{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'burgers', 'title': 'Burgers'}]",
#  "[{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'portuguese', 'title': 'Portuguese'}]",
#  "[{'alias': 'spas', 'title': 'Day Spas'}, {'alias': 'gaybars', 'title': 'Gay Bars'}]",
#  "[{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'seafood', 'title': 'Seafood'}]",
#  "[{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}]",
#  "[{'alias': 'raw_food', 'title': 'Live/Raw Food'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'vegan', 'title': 'Vegan'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]",
#  "[{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'thai', 'title': 'Thai'}, {'alias': 'chinese', 'title': 'Chinese'}]",
#  "[{'alias': 'halal', 'title': 'Halal'}, {'alias': 'bakeries', 'title': 'Bakeries'}]",
#  "[{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'spanish', 'title': 'Spanish'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'peruvian', 'title': 'Peruvian'}, {'alias': 'buffets', 'title': 'Buffets'}]",
#  "[{'alias': 'argentine', 'title': 'Argentine'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'bars', 'title': 'Bars'}]",
#  "[{'alias': 'hungarian', 'title': 'Hungarian'}, {'alias': 'bistros', 'title': 'Bistros'}]",
#  "[{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'filipino', 'title': 'Filipino'}]",
#  "[{'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'alias': 'burgers', 'title': 'Burgers'}]",
#  "[{'alias': 'german', 'title': 'German'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'salad', 'title': 'Salad'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'organic_stores', 'title': 'Organic Stores'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'gourmet', 'title': 'Specialty Food'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'arcades', 'title': 'Arcades'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'delis', 'title': 'Delis'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'diners', 'title': 'Diners'}]",
#  "[{'alias': 'mediterranean', 'title': 'Mediterranean'}]",
#  "[{'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'importedfood', 'title': 'Imported Food'}, {'alias': 'meats', 'title': 'Meat Shops'}]",
#  "[{'alias': 'delis', 'title': 'Delis'}, {'alias': 'meats', 'title': 'Meat Shops'}, {'alias': 'smokehouse', 'title': 'Smokehouse'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'soup', 'title': 'Soup'}]",
#  "[{'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'bagels', 'title': 'Bagels'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'chinese', 'title': 'Chinese'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'taiwanese', 'title': 'Taiwanese'}, {'alias': 'importedfood', 'title': 'Imported Food'}]",
#  "[{'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'bagels', 'title': 'Bagels'}]",
#  "[{'alias': 'wine_bars', 'title': 'Wine Bars'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'chinese', 'title': 'Chinese'}]",
#  "[{'alias': 'russian', 'title': 'Russian'}, {'alias': 'lounges', 'title': 'Lounges'}]",
#  "[{'alias': 'fishnchips', 'title': 'Fish & Chips'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'steak', 'title': 'Steakhouses'}]",
#  "[{'alias': 'pubs', 'title': 'Pubs'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'musicvenues', 'title': 'Music Venues'}]",
#  "[{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'cantonese', 'title': 'Cantonese'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'tea', 'title': 'Tea Rooms'}]",
#  "[{'alias': 'greek', 'title': 'Greek'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'thai', 'title': 'Thai'}, {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}]",
#  "[{'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}, {'alias': 'indpak', 'title': 'Indian'}]",
#  "[{'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'falafel', 'title': 'Falafel'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'venezuelan', 'title': 'Venezuelan'}, {'alias': 'gluten_free', 'title': 'Gluten-Free'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'thai', 'title': 'Thai'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'catering', 'title': 'Caterers'}]",
#  "[{'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'thai', 'title': 'Thai'}]",
#  "[{'alias': 'farmersmarket', 'title': 'Farmers Market'}, {'alias': 'gourmet', 'title': 'Specialty Food'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'thai', 'title': 'Thai'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}]",
#  "[{'alias': 'breweries', 'title': 'Breweries'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}]",
#  "[{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'seafood', 'title': 'Seafood'}]",
#  "[{'alias': 'salad', 'title': 'Salad'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'artclasses', 'title': 'Art Classes'}, {'alias': 'jewelry', 'title': 'Jewelry'}, {'alias': 'teambuilding', 'title': 'Team Building Activities'}]",
#  "[{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'healthmarkets', 'title': 'Health Markets'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'bubbletea', 'title': 'Bubble Tea'}, {'alias': 'poke', 'title': 'Poke'}]",
#  "[{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'bubbletea', 'title': 'Bubble Tea'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]",
#  "[{'alias': 'thai', 'title': 'Thai'}, {'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]",
#  "[{'alias': 'french', 'title': 'French'}, {'alias': 'bistros', 'title': 'Bistros'}]",
#  "[{'alias': 'delis', 'title': 'Delis'}, {'alias': 'polish', 'title': 'Polish'}, {'alias': 'ukrainian', 'title': 'Ukrainian'}]",
#  "[{'alias': 'wine_bars', 'title': 'Wine Bars'}, {'alias': 'diners', 'title': 'Diners'}, {'alias': 'salad', 'title': 'Salad'}]",
#  "[{'alias': 'ramen', 'title': 'Ramen'}, {'alias': 'desserts', 'title': 'Desserts'}]",
#  "[{'alias': 'wine_bars', 'title': 'Wine Bars'}, {'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]",
#  "[{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'taiwanese', 'title': 'Taiwanese'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]",
#  "[{'alias': 'fishnchips', 'title': 'Fish & Chips'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'comfortfood', 'title': 'Comfort Food'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'salad', 'title': 'Salad'}, {'alias': 'vegan', 'title': 'Vegan'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}]",
#  "[{'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'salad', 'title': 'Salad'}]",
#  "[{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'vietnamese', 'title': 'Vietnamese'}]",
#  "[{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'buffets', 'title': 'Buffets'}]",
#  "[{'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}]",
#  "[{'alias': 'korean', 'title': 'Korean'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'mexican', 'title': 'Mexican'}]",
#  "[{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'portuguese', 'title': 'Portuguese'}]",
#  "[{'alias': 'creperies', 'title': 'Creperies'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'waffles', 'title': 'Waffles'}]",
#  "[{'alias': 'hookah_bars', 'title': 'Hookah Bars'}, {'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'mideastern', 'title': 'Middle Eastern'}]",
#  "[{'alias': 'mideastern', 'title': 'Middle Eastern'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'greek', 'title': 'Greek'}]",
#  "[{'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'halal', 'title': 'Halal'}]",
#  "[{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'foodstands', 'title': 'Food Stands'}]",
#  "[{'alias': 'kosher', 'title': 'Kosher'}, {'alias': 'mideastern', 'title': 'Middle Eastern'}]",
#  "[{'alias': 'african', 'title': 'African'}, {'alias': 'mideastern', 'title': 'Middle Eastern'}]",
#  "[{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'malaysian', 'title': 'Malaysian'}, {'alias': 'thai', 'title': 'Thai'}]",
#  "[{'alias': 'caribbean', 'title': 'Caribbean'}, {'alias': 'indpak', 'title': 'Indian'}]",
#  "[{'alias': 'social_clubs', 'title': 'Social Clubs'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}]",
#  "[{'alias': 'pubs', 'title': 'Pubs'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'soup', 'title': 'Soup'}]",
#  "[{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'importedfood', 'title': 'Imported Food'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'bbq', 'title': 'Barbeque'}]",
#  "[{'alias': 'halal', 'title': 'Halal'}, {'alias': 'mideastern', 'title': 'Middle Eastern'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'caribbean', 'title': 'Caribbean'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'gluten_free', 'title': 'Gluten-Free'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}]",
#  "[{'alias': 'foodstands', 'title': 'Food Stands'}, {'alias': 'waffles', 'title': 'Waffles'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'karaoke', 'title': 'Karaoke'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]",
#  "[{'alias': 'pubs', 'title': 'Pubs'}, {'alias': 'british', 'title': 'British'}]",
#  "[{'alias': 'chickenshop', 'title': 'Chicken Shop'}, {'alias': 'beerbar', 'title': 'Beer Bar'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]",
#  "[{'alias': 'brazilian', 'title': 'Brazilian'}, {'alias': 'steak', 'title': 'Steakhouses'}]",
#  "[{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'sushi', 'title': 'Sushi Bars'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}]",
#  "[{'alias': 'homecleaning', 'title': 'Home Cleaning'}, {'alias': 'bartenders', 'title': 'Bartenders'}, {'alias': 'personalchefs', 'title': 'Personal Chefs'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'bakeries', 'title': 'Bakeries'}]",
#  "[{'alias': 'venues', 'title': 'Venues & Event Spaces'}, {'alias': 'lounges', 'title': 'Lounges'}, {'alias': 'danceclubs', 'title': 'Dance Clubs'}]",
#  "[{'alias': 'german', 'title': 'German'}]",
#  "[{'alias': 'pakistani', 'title': 'Pakistani'}, {'alias': 'halal', 'title': 'Halal'}, {'alias': 'indpak', 'title': 'Indian'}]",
#  "[{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'salad', 'title': 'Salad'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'burgers', 'title': 'Burgers'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'korean', 'title': 'Korean'}]",
#  "[{'alias': 'vegan', 'title': 'Vegan'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'lounges', 'title': 'Lounges'}]",
#  "[{'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'bakeries', 'title': 'Bakeries'}]",
#  "[{'alias': 'dimsum', 'title': 'Dim Sum'}, {'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'bakeries', 'title': 'Bakeries'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'donuts', 'title': 'Donuts'}]",
#  "[{'alias': 'mideastern', 'title': 'Middle Eastern'}]",
#  "[{'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}, {'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'indpak', 'title': 'Indian'}]",
#  "[{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'lebanese', 'title': 'Lebanese'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'halal', 'title': 'Halal'}, {'alias': 'bangladeshi', 'title': 'Bangladeshi'}]",
#  "[{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]",
#  "[{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'eventplanning', 'title': 'Party & Event Planning'}]",
#  "[{'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'gourmet', 'title': 'Specialty Food'}, {'alias': 'caribbean', 'title': 'Caribbean'}]",
#  "[{'alias': 'caribbean', 'title': 'Caribbean'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'importedfood', 'title': 'Imported Food'}]",
#  "[{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'italian', 'title': 'Italian'}]",
#  "[{'alias': 'italian', 'title': 'Italian'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'greek', 'title': 'Greek'}]",
#  "[{'alias': 'mideastern', 'title': 'Middle Eastern'}, {'alias': 'food_court', 'title': 'Food Court'}, {'alias': 'importedfood', 'title': 'Imported Food'}]",
#  "[{'alias': 'thai', 'title': 'Thai'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'delis', 'title': 'Delis'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'catering', 'title': 'Caterers'}]",
#  "[{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'thai', 'title': 'Thai'}, {'alias': 'hakka', 'title': 'Hakka'}]",
#  "[{'alias': 'tapas', 'title': 'Tapas Bars'}, {'alias': 'spanish', 'title': 'Spanish'}, {'alias': 'bars', 'title': 'Bars'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'creperies', 'title': 'Creperies'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'italian', 'title': 'Italian'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'hakka', 'title': 'Hakka'}, {'alias': 'thai', 'title': 'Thai'}]",
#  "[{'alias': 'raw_food', 'title': 'Live/Raw Food'}, {'alias': 'organic_stores', 'title': 'Organic Stores'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'caribbean', 'title': 'Caribbean'}]",
#  "[{'alias': 'beerbar', 'title': 'Beer Bar'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'italian', 'title': 'Italian'}]",
#  "[{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'fishnchips', 'title': 'Fish & Chips'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'pianobars', 'title': 'Piano Bars'}, {'alias': 'musicvenues', 'title': 'Music Venues'}]",
#  "[{'alias': 'delicatessen', 'title': 'Delicatessen'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'importedfood', 'title': 'Imported Food'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'divebars', 'title': 'Dive Bars'}, {'alias': 'comfortfood', 'title': 'Comfort Food'}]",
#  "[{'alias': 'caribbean', 'title': 'Caribbean'}, {'alias': 'soup', 'title': 'Soup'}, {'alias': 'importedfood', 'title': 'Imported Food'}]",
#  "[{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'thai', 'title': 'Thai'}]",
#  "[{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'healthmarkets', 'title': 'Health Markets'}]",
#  "[{'alias': 'italian', 'title': 'Italian'}, {'alias': 'brasseries', 'title': 'Brasseries'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]",
#  "[{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}, {'alias': 'korean', 'title': 'Korean'}]",
#  "[{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'lebanese', 'title': 'Lebanese'}]",
#  "[{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'kosher', 'title': 'Kosher'}]",
#  "[{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'healthmarkets', 'title': 'Health Markets'}]",
#  "[{'alias': 'kosher', 'title': 'Kosher'}, {'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'japanese', 'title': 'Japanese'}]",
#  "[{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'buffets', 'title': 'Buffets'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'creperies', 'title': 'Creperies'}]",
#  "[{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}]",
#  "[{'alias': 'lebanese', 'title': 'Lebanese'}]",
#  "[{'alias': 'spanish', 'title': 'Spanish'}, {'alias': 'latin', 'title': 'Latin American'}, {'alias': 'bars', 'title': 'Bars'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'creperies', 'title': 'Creperies'}]",
#  "[{'alias': 'wine_bars', 'title': 'Wine Bars'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'hookah_bars', 'title': 'Hookah Bars'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'lounges', 'title': 'Lounges'}]",
#  "[{'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'comfortfood', 'title': 'Comfort Food'}, {'alias': 'bars', 'title': 'Bars'}]",
#  "[{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}]",
#  "[{'alias': 'french', 'title': 'French'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}, {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}]",
#  "[{'alias': 'mideastern', 'title': 'Middle Eastern'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'cajun', 'title': 'Cajun/Creole'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'caribbean', 'title': 'Caribbean'}]",
#  "[{'alias': 'mideastern', 'title': 'Middle Eastern'}, {'alias': 'falafel', 'title': 'Falafel'}]",
#  "[{'alias': 'hotels', 'title': 'Hotels'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]",
#  "[{'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'gaybars', 'title': 'Gay Bars'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'macarons', 'title': 'Macarons'}]",
#  "[{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'italian', 'title': 'Italian'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'salad', 'title': 'Salad'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'donuts', 'title': 'Donuts'}]",
#  "[{'alias': 'korean', 'title': 'Korean'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'korean', 'title': 'Korean'}, {'alias': 'beerbar', 'title': 'Beer Bar'}]",
#  "[{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'mideastern', 'title': 'Middle Eastern'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'gourmet', 'title': 'Specialty Food'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'greek', 'title': 'Greek'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'srilankan', 'title': 'Sri Lankan'}]",
#  "[{'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'dimsum', 'title': 'Dim Sum'}, {'alias': 'sushi', 'title': 'Sushi Bars'}]",
#  "[{'alias': 'venues', 'title': 'Venues & Event Spaces'}, {'alias': 'italian', 'title': 'Italian'}]",
#  "[{'alias': 'korean', 'title': 'Korean'}, {'alias': 'seafood', 'title': 'Seafood'}]",
#  "[{'alias': 'gourmet', 'title': 'Specialty Food'}, {'alias': 'soup', 'title': 'Soup'}]",
#  "[{'alias': 'halal', 'title': 'Halal'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'korean', 'title': 'Korean'}, {'alias': 'burgers', 'title': 'Burgers'}]",
#  "[{'alias': 'mideastern', 'title': 'Middle Eastern'}, {'alias': 'arabian', 'title': 'Arabian'}, {'alias': 'falafel', 'title': 'Falafel'}]",
#  "[{'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'italian', 'title': 'Italian'}]",
#  "[{'alias': 'salad', 'title': 'Salad'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'gluten_free', 'title': 'Gluten-Free'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]",
#  "[{'alias': 'cheese', 'title': 'Cheese Shops'}, {'alias': 'delicatessen', 'title': 'Delicatessen'}]",
#  "[{'alias': 'chickenshop', 'title': 'Chicken Shop'}, {'alias': 'portuguese', 'title': 'Portuguese'}]",
#  "[{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'thai', 'title': 'Thai'}]",
#  "[{'alias': 'brasseries', 'title': 'Brasseries'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'thai', 'title': 'Thai'}, {'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'taiwanese', 'title': 'Taiwanese'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'french', 'title': 'French'}, {'alias': 'bistros', 'title': 'Bistros'}, {'alias': 'diners', 'title': 'Diners'}]",
#  "[{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'lounges', 'title': 'Lounges'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]",
#  "[{'alias': 'venues', 'title': 'Venues & Event Spaces'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'supperclubs', 'title': 'Supper Clubs'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'bagels', 'title': 'Bagels'}, {'alias': 'bakeries', 'title': 'Bakeries'}]",
#  "[{'alias': 'lounges', 'title': 'Lounges'}, {'alias': 'danceclubs', 'title': 'Dance Clubs'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]",
#  "[{'alias': 'italian', 'title': 'Italian'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'musicalinstrumentsandteachers', 'title': 'Musical Instruments & Teachers'}]",
#  "[{'alias': 'spanish', 'title': 'Spanish'}, {'alias': 'latin', 'title': 'Latin American'}, {'alias': 'bbq', 'title': 'Barbeque'}]",
#  "[{'alias': 'gourmet', 'title': 'Specialty Food'}, {'alias': 'kitchenandbath', 'title': 'Kitchen & Bath'}]",
#  "[{'alias': 'boxing', 'title': 'Boxing'}, {'alias': 'muaythai', 'title': 'Muay Thai'}]",
#  "[{'alias': 'halal', 'title': 'Halal'}, {'alias': 'chickenshop', 'title': 'Chicken Shop'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]",
#  "[{'alias': 'mongolian', 'title': 'Mongolian'}, {'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'bbq', 'title': 'Barbeque'}]",
#  "[{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'salad', 'title': 'Salad'}]",
#  "[{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]",
#  "[{'alias': 'markets', 'title': 'Fruits & Veggies'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'meats', 'title': 'Meat Shops'}, {'alias': 'delis', 'title': 'Delis'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'creperies', 'title': 'Creperies'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'thai', 'title': 'Thai'}, {'alias': 'filipino', 'title': 'Filipino'}]",
#  "[{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'burgers', 'title': 'Burgers'}]",
#  "[{'alias': 'greek', 'title': 'Greek'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]",
#  "[{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'korean', 'title': 'Korean'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'bubbletea', 'title': 'Bubble Tea'}]",
#  "[{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'british', 'title': 'British'}]",
#  "[{'alias': 'halal', 'title': 'Halal'}, {'alias': 'pakistani', 'title': 'Pakistani'}]",
#  "[{'alias': 'hotdog', 'title': 'Hot Dogs'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'delis', 'title': 'Delis'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}, {'alias': 'macarons', 'title': 'Macarons'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'gluten_free', 'title': 'Gluten-Free'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]",
#  "[{'alias': 'mongolian', 'title': 'Mongolian'}, {'alias': 'hotpot', 'title': 'Hot Pot'}, {'alias': 'chinese', 'title': 'Chinese'}]",
#  "[{'alias': 'mideastern', 'title': 'Middle Eastern'}, {'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'bbq', 'title': 'Barbeque'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'turkish', 'title': 'Turkish'}, {'alias': 'internetcafe', 'title': 'Internet Cafes'}]",
#  "[{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#  "[{'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'chinese', 'title': 'Chinese'}]",
#  "[{'alias': 'greek', 'title': 'Greek'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}, {'alias': 'customcakes', 'title': 'Custom Cakes'}, {'alias': 'bakeries', 'title': 'Bakeries'}]",
#  "[{'alias': 'ramen', 'title': 'Ramen'}]",
#  "[{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'pizza', 'title': 'Pizza'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'bbq', 'title': 'Barbeque'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'arts', 'title': 'Arts & Entertainment'}, {'alias': 'teambuilding', 'title': 'Team Building Activities'}]",
#  "[{'alias': 'poutineries', 'title': 'Poutineries'}, {'alias': 'delis', 'title': 'Delis'}]",
#  "[{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'korean', 'title': 'Korean'}, {'alias': 'japanese', 'title': 'Japanese'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'pizza', 'title': 'Pizza'}]",
#  "[{'alias': 'lounges', 'title': 'Lounges'}, {'alias': 'tapas', 'title': 'Tapas Bars'}]",
#  "[{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'waffles', 'title': 'Waffles'}, {'alias': 'belgian', 'title': 'Belgian'}]",
#  "[{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'thai', 'title': 'Thai'}, {'alias': 'chinese', 'title': 'Chinese'}]",
#  "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}, {'alias': 'pizza', 'title': 'Pizza'}]",
#  "[{'alias': 'southern', 'title': 'Southern'}, {'alias': 'chickenshop', 'title': 'Chicken Shop'}, {'alias': 'cajun', 'title': 'Cajun/Creole'}]",
#  "[{'alias': 'food_court', 'title': 'Food Court'}, {'alias': 'greek', 'title': 'Greek'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'foodtours', 'title': 'Food Tours'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'delis', 'title': 'Delis'}]",
#  "[{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'gastropubs', 'title': 'Gastropubs'}]",
#  "[{'alias': 'musicvenues', 'title': 'Music Venues'}, {'alias': 'pubs', 'title': 'Pubs'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]",
#  "[{'alias': 'importedfood', 'title': 'Imported Food'}]",
#  "[{'alias': 'gluten_free', 'title': 'Gluten-Free'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'healthmarkets', 'title': 'Health Markets'}]",
#  "[{'alias': 'brazilian', 'title': 'Brazilian'}, {'alias': 'catering', 'title': 'Caterers'}]",
#  "[{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'diners', 'title': 'Diners'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'diners', 'title': 'Diners'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'french', 'title': 'French'}]",
#  "[{'alias': 'taiwanese', 'title': 'Taiwanese'}, {'alias': 'bubbletea', 'title': 'Bubble Tea'}, {'alias': 'desserts', 'title': 'Desserts'}]",
#  "[{'alias': 'venues', 'title': 'Venues & Event Spaces'}, {'alias': 'catering', 'title': 'Caterers'}, {'alias': 'eventplanning', 'title': 'Party & Event Planning'}]",
#  "[{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'steak', 'title': 'Steakhouses'}]",
#  "[{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'chickenshop', 'title': 'Chicken Shop'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]",
#  "[{'alias': 'halal', 'title': 'Halal'}, {'alias': 'italian', 'title': 'Italian'}]",
#  "[{'alias': 'halal', 'title': 'Halal'}, {'alias': 'portuguese', 'title': 'Portuguese'}, {'alias': 'burgers', 'title': 'Burgers'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'syrian', 'title': 'Syrian'}]",
#  "[{'alias': 'irish', 'title': 'Irish'}, {'alias': 'steak', 'title': 'Steakhouses'}]",
#  "[{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'bubbletea', 'title': 'Bubble Tea'}]",
#  "[{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}]",
#  "[{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#  "[{'alias': 'musicvenues', 'title': 'Music Venues'}, {'alias': 'lounges', 'title': 'Lounges'}]",
#  "[{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'poutineries', 'title': 'Poutineries'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}]",
#  "[{'alias': 'vegan', 'title': 'Vegan'}, {'alias': 'italian', 'title': 'Italian'}]",
#  "[{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'pubs', 'title': 'Pubs'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'musicvenues', 'title': 'Music Venues'}]",
#  "[{'alias': 'arabian', 'title': 'Arabian'}]",
#  "[{'alias': 'internetcafe', 'title': 'Internet Cafes'}]",
#  "[{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'wedding_planning', 'title': 'Wedding Planning'}, {'alias': 'eventplanning', 'title': 'Party & Event Planning'}]",
#  "[{'alias': 'cheese', 'title': 'Cheese Shops'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'pubs', 'title': 'Pubs'}]",
#  "[{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}, {'alias': 'mexican', 'title': 'Mexican'}]",
#  "[{'alias': 'chickenshop', 'title': 'Chicken Shop'}, {'alias': 'waffles', 'title': 'Waffles'}, {'alias': 'burgers', 'title': 'Burgers'}]",
#  "[{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'diners', 'title': 'Diners'}]",
#  "[{'alias': 'russian', 'title': 'Russian'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}]",
#  "[{'alias': 'pubs', 'title': 'Pubs'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]",
#  "[{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'french', 'title': 'French'}]",
#  "[{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'soup', 'title': 'Soup'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'korean', 'title': 'Korean'}, {'alias': 'mexican', 'title': 'Mexican'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'halal', 'title': 'Halal'}, {'alias': 'turkish', 'title': 'Turkish'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'social_clubs', 'title': 'Social Clubs'}]",
#  "[{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'steak', 'title': 'Steakhouses'}]",
#  "[{'alias': 'singaporean', 'title': 'Singaporean'}, {'alias': 'thai', 'title': 'Thai'}, {'alias': 'malaysian', 'title': 'Malaysian'}]",
#  "[{'alias': 'fishnchips', 'title': 'Fish & Chips'}]",
#  "[{'alias': 'lounges', 'title': 'Lounges'}]",
#  "[{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'turkish', 'title': 'Turkish'}]",
#  "[{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'burgers', 'title': 'Burgers'}]",
#  "[{'alias': 'cajun', 'title': 'Cajun/Creole'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'korean', 'title': 'Korean'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'buffets', 'title': 'Buffets'}]",
#  "[{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'bars', 'title': 'Bars'}]",
#  "[{'alias': 'mideastern', 'title': 'Middle Eastern'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]",
#  "[{'alias': 'bubbletea', 'title': 'Bubble Tea'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'bars', 'title': 'Bars'}]",
#  "[{'alias': 'waffles', 'title': 'Waffles'}, {'alias': 'chickenshop', 'title': 'Chicken Shop'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'pizza', 'title': 'Pizza'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'bakeries', 'title': 'Bakeries'}]",
#  "[{'alias': 'fishnchips', 'title': 'Fish & Chips'}, {'alias': 'thai', 'title': 'Thai'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'chickenshop', 'title': 'Chicken Shop'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]",
#  "[{'alias': 'delis', 'title': 'Delis'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'meats', 'title': 'Meat Shops'}]",
#  "[{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'brazilian', 'title': 'Brazilian'}, {'alias': 'latin', 'title': 'Latin American'}]",
#  "[{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'noodles', 'title': 'Noodles'}]",
#  "[{'alias': 'delis', 'title': 'Delis'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'cheese', 'title': 'Cheese Shops'}]",
#  "[{'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'arcades', 'title': 'Arcades'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'healthmarkets', 'title': 'Health Markets'}]",
#  "[{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]",
#  "[{'alias': 'korean', 'title': 'Korean'}, {'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'sushi', 'title': 'Sushi Bars'}]",
#  "[{'alias': 'barreclasses', 'title': 'Barre Classes'}]",
#  "[{'alias': 'salad', 'title': 'Salad'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'german', 'title': 'German'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'gluten_free', 'title': 'Gluten-Free'}]",
#  "[{'alias': 'german', 'title': 'German'}, {'alias': 'delis', 'title': 'Delis'}]",
#  "[{'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'diners', 'title': 'Diners'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'bubbletea', 'title': 'Bubble Tea'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'korean', 'title': 'Korean'}]",
#  "[{'alias': 'musicalinstrumentsandteachers', 'title': 'Musical Instruments & Teachers'}, {'alias': 'pianoservices', 'title': 'Piano Services'}, {'alias': 'pianostores', 'title': 'Piano Stores'}]",
#  "[{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'laundromat', 'title': 'Laundromat'}]",
#  "[{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'korean', 'title': 'Korean'}]",
#  "[{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'artclasses', 'title': 'Art Classes'}]",
#  "[{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'hotdog', 'title': 'Hot Dogs'}]",
#  "[{'alias': 'divebars', 'title': 'Dive Bars'}, {'alias': 'danceclubs', 'title': 'Dance Clubs'}]",
#  "[{'alias': 'artclasses', 'title': 'Art Classes'}, {'alias': 'musicalinstrumentsandteachers', 'title': 'Musical Instruments & Teachers'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'donuts', 'title': 'Donuts'}]",
# ...
#  "[{'alias': 'spanish', 'title': 'Spanish'}, {'alias': 'tapas', 'title': 'Tapas Bars'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'creperies', 'title': 'Creperies'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'gourmet', 'title': 'Specialty Food'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'australian', 'title': 'Australian'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'chickenshop', 'title': 'Chicken Shop'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]",
#  "[{'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'vietnamese', 'title': 'Vietnamese'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'galleries', 'title': 'Art Galleries'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'pizza', 'title': 'Pizza'}]",
#  "[{'alias': 'southern', 'title': 'Southern'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}]",
#  "[{'alias': 'filipino', 'title': 'Filipino'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'bbq', 'title': 'Barbeque'}]",
#  "[{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'italian', 'title': 'Italian'}]",
#  "[{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'poke', 'title': 'Poke'}]",
#  "[{'alias': 'austrian', 'title': 'Austrian'}]",
#  "[{'alias': 'ethiopian', 'title': 'Ethiopian'}, {'alias': 'african', 'title': 'African'}]",
#  "[{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'desserts', 'title': 'Desserts'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'seafood', 'title': 'Seafood'}]",
#  "[{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'chickenshop', 'title': 'Chicken Shop'}]",
#  "[{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'bbq', 'title': 'Barbeque'}]",
#  "[{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}]",
#  "[{'alias': 'cheese', 'title': 'Cheese Shops'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'bubbletea', 'title': 'Bubble Tea'}, {'alias': 'chinese', 'title': 'Chinese'}]",
#  "[{'alias': 'caribbean', 'title': 'Caribbean'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'diners', 'title': 'Diners'}]",
#  "[{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'desserts', 'title': 'Desserts'}]",
#  "[{'alias': 'foodbanks', 'title': 'Food Banks'}]",
#  "[{'alias': 'chickenshop', 'title': 'Chicken Shop'}, {'alias': 'cajun', 'title': 'Cajun/Creole'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}]",
#  "[{'alias': 'venues', 'title': 'Venues & Event Spaces'}, {'alias': 'catering', 'title': 'Caterers'}]",
#  "[{'alias': 'hawaiian', 'title': 'Hawaiian'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'guesthouses', 'title': 'Guest Houses'}, {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}]",
#  "[{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'kosher', 'title': 'Kosher'}]",
#  "[{'alias': 'caribbean', 'title': 'Caribbean'}, {'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'bars', 'title': 'Bars'}]",
#  "[{'alias': 'eventplanning', 'title': 'Party & Event Planning'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]",
#  "[{'alias': 'bistros', 'title': 'Bistros'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]",
#  "[{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]",
#  "[{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'soup', 'title': 'Soup'}, {'alias': 'chinese', 'title': 'Chinese'}]",
#  "[{'alias': 'kosher', 'title': 'Kosher'}, {'alias': 'bagels', 'title': 'Bagels'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]",
#  "[{'alias': 'pubs', 'title': 'Pubs'}, {'alias': 'irish', 'title': 'Irish'}]",
#  "[{'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'desserts', 'title': 'Desserts'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]",
#  "[{'alias': 'pubs', 'title': 'Pubs'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]",
#  "[{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'burgers', 'title': 'Burgers'}]",
#  "[{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'beerbar', 'title': 'Beer Bar'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]",
#  "[{'alias': 'wine_bars', 'title': 'Wine Bars'}, {'alias': 'italian', 'title': 'Italian'}]",
#  "[{'alias': 'hawaiian', 'title': 'Hawaiian'}, {'alias': 'poke', 'title': 'Poke'}]",
#  "[{'alias': 'salad', 'title': 'Salad'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'privatetutors', 'title': 'Private Tutors'}, {'alias': 'musicalinstrumentsandteachers', 'title': 'Musical Instruments & Teachers'}]",
#  "[{'alias': 'persian', 'title': 'Persian/Iranian'}, {'alias': 'mideastern', 'title': 'Middle Eastern'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}]",
#  "[{'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}, {'alias': 'guesthouses', 'title': 'Guest Houses'}]",
#  "[{'alias': 'delis', 'title': 'Delis'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'steak', 'title': 'Steakhouses'}]",
#  "[{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'mideastern', 'title': 'Middle Eastern'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]",
#  "[{'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'dimsum', 'title': 'Dim Sum'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]",
#  "[{'alias': 'karaoke', 'title': 'Karaoke'}, {'alias': 'lounges', 'title': 'Lounges'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'delicatessen', 'title': 'Delicatessen'}]",
#  "[{'alias': 'egyptian', 'title': 'Egyptian'}, {'alias': 'halal', 'title': 'Halal'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'danceclubs', 'title': 'Dance Clubs'}, {'alias': 'musicvenues', 'title': 'Music Venues'}]",
#  "[{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'vegan', 'title': 'Vegan'}]",
#  "[{'alias': 'comfortfood', 'title': 'Comfort Food'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}]",
#  "[{'alias': 'southern', 'title': 'Southern'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#  "[{'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'salad', 'title': 'Salad'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'gluten_free', 'title': 'Gluten-Free'}]",
#  "[{'alias': 'kebab', 'title': 'Kebab'}, {'alias': 'afghani', 'title': 'Afghan'}]",
#  "[{'alias': 'pubs', 'title': 'Pubs'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'irish', 'title': 'Irish'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'musicvenues', 'title': 'Music Venues'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'fishnchips', 'title': 'Fish & Chips'}]",
#  "[{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'thai', 'title': 'Thai'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'gourmet', 'title': 'Specialty Food'}, {'alias': 'chinese', 'title': 'Chinese'}]",
#  "[{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'smokehouse', 'title': 'Smokehouse'}]",
#  "[{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'korean', 'title': 'Korean'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'pizza', 'title': 'Pizza'}]",
#  "[{'alias': 'irish', 'title': 'Irish'}, {'alias': 'pubs', 'title': 'Pubs'}, {'alias': 'lounges', 'title': 'Lounges'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'chickenshop', 'title': 'Chicken Shop'}, {'alias': 'korean', 'title': 'Korean'}, {'alias': 'bars', 'title': 'Bars'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'burgers', 'title': 'Burgers'}]",
#  "[{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}, {'alias': 'bakeries', 'title': 'Bakeries'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'greek', 'title': 'Greek'}]",
#  "[{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'beerbar', 'title': 'Beer Bar'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}, {'alias': 'macarons', 'title': 'Macarons'}]",
#  "[{'alias': 'mideastern', 'title': 'Middle Eastern'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]",
#  "[{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'soup', 'title': 'Soup'}]",
#  "[{'alias': 'kosher', 'title': 'Kosher'}, {'alias': 'bakeries', 'title': 'Bakeries'}]",
#  "[{'alias': 'halal', 'title': 'Halal'}, {'alias': 'bangladeshi', 'title': 'Bangladeshi'}]",
#  "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'ukrainian', 'title': 'Ukrainian'}, {'alias': 'polish', 'title': 'Polish'}]",
#  "[{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'galleries', 'title': 'Art Galleries'}]",
#  "[{'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}, {'alias': 'food_court', 'title': 'Food Court'}]",
#  "[{'alias': 'caribbean', 'title': 'Caribbean'}, {'alias': 'lounges', 'title': 'Lounges'}, {'alias': 'cafes', 'title': 'Cafes'}]",
#  "[{'alias': 'whiskeybars', 'title': 'Whiskey Bars'}]",
#  "[{'alias': 'turkish', 'title': 'Turkish'}, {'alias': 'bars', 'title': 'Bars'}]",
#  "[{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'latin', 'title': 'Latin American'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'cajun', 'title': 'Cajun/Creole'}, {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}]",
#  "[{'alias': 'lebanese', 'title': 'Lebanese'}, {'alias': 'halal', 'title': 'Halal'}]",
#  "[{'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  "[{'alias': 'german', 'title': 'German'}, {'alias': 'beerbar', 'title': 'Beer Bar'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}]",
#  "[{'alias': 'foodstands', 'title': 'Food Stands'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'noodles', 'title': 'Noodles'}, {'alias': 'thai', 'title': 'Thai'}]",
#  "[{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'thai', 'title': 'Thai'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'donuts', 'title': 'Donuts'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]",
#  "[{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'catering', 'title': 'Caterers'}]",
#  "[{'alias': 'comedyclubs', 'title': 'Comedy Clubs'}, {'alias': 'comfortfood', 'title': 'Comfort Food'}, {'alias': 'diners', 'title': 'Diners'}]",
#  "[{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'delis', 'title': 'Delis'}]",
#  "[{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}]",
#  "[{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}]",
#  "[{'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}, {'alias': 'organic_stores', 'title': 'Organic Stores'}]",
#  "[{'alias': 'bars', 'title': 'Bars'}, {'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'tabletopgames', 'title': 'Tabletop Games'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'bbq', 'title': 'Barbeque'}]",
#  "[{'alias': 'buffets', 'title': 'Buffets'}, {'alias': 'indpak', 'title': 'Indian'}]",
#  "[{'alias': 'customcakes', 'title': 'Custom Cakes'}, {'alias': 'bakeries', 'title': 'Bakeries'}]",
#  "[{'alias': 'localflavor', 'title': 'Local Flavor'}, {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}, {'alias': 'pubs', 'title': 'Pubs'}]",
#  "[{'alias': 'poolhalls', 'title': 'Pool Halls'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]",
#  "[{'alias': 'soup', 'title': 'Soup'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]",
#  "[{'alias': 'thai', 'title': 'Thai'}, {'alias': 'malaysian', 'title': 'Malaysian'}]",
#  "[{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'chinese', 'title': 'Chinese'}]",
#  "[{'alias': 'kosher', 'title': 'Kosher'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'bagels', 'title': 'Bagels'}]",
#  "[{'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]",
#  "[{'alias': 'russian', 'title': 'Russian'}, {'alias': 'ukrainian', 'title': 'Ukrainian'}]",
#  "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'waffles', 'title': 'Waffles'}]",
#  "[{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'bubbletea', 'title': 'Bubble Tea'}]",
#  "[{'alias': 'kitchenandbath', 'title': 'Kitchen & Bath'}, {'alias': 'gourmet', 'title': 'Specialty Food'}]",
#  "[{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}, {'alias': 'butcher', 'title': 'Butcher'}]",
#  "[{'alias': 'cheese', 'title': 'Cheese Shops'}, {'alias': 'comfortfood', 'title': 'Comfort Food'}]",
#  "[{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}]",
#  "[{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#  ...}

# %%
df[df['categories'].str.contains('Food Trucks')].categories.values
# Out:
# array(["[{'alias': 'venezuelan', 'title': 'Venezuelan'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'southern', 'title': 'Southern'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]",
#        "[{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'gourmet', 'title': 'Specialty Food'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'vegan', 'title': 'Vegan'}]",
#        "[{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'bbq', 'title': 'Barbeque'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'catering', 'title': 'Caterers'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'burgers', 'title': 'Burgers'}]",
#        "[{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'southern', 'title': 'Southern'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'gourmet', 'title': 'Specialty Food'}]",
#        "[{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'mideastern', 'title': 'Middle Eastern'}, {'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'catering', 'title': 'Caterers'}]",
#        "[{'alias': 'waffles', 'title': 'Waffles'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'catering', 'title': 'Caterers'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'catering', 'title': 'Caterers'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'streetvendors', 'title': 'Street Vendors'}, {'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'venezuelan', 'title': 'Venezuelan'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'burgers', 'title': 'Burgers'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'newcanadian', 'title': 'Canadian (New)'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'mexican', 'title': 'Mexican'}]",
#        "[{'alias': 'bubbletea', 'title': 'Bubble Tea'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'bbq', 'title': 'Barbeque'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'catering', 'title': 'Caterers'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'indpak', 'title': 'Indian'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'streetvendors', 'title': 'Street Vendors'}, {'alias': 'importedfood', 'title': 'Imported Food'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]",
#        "[{'alias': 'foodtrucks', 'title': 'Food Trucks'}]"], dtype=object)

# %%
len(df[df['longitude'] == 'None'])
# Out:
# 0

# %%
filename = "..\\data\\Cleaned_Toronto_Reviews.json"
with open(filename,'r') as f:
        data = f.readlines()
        data = list(map(json.loads, data))
    
data = data[0]
#Get all the data from the dggeata file
df_reviews = pd.DataFrame(data)

# %%
df_reviews.head(2)
# Out:
#    Day  Month  Unnamed: 0.1  Unnamed: 0_x  Unnamed: 0_y  Updated  Year  \
# 0   23      8             6             6         21653    False  2016
# 1    2     10             7             7         21653    False  2016
#
#                  alias             business_id  business_stars  \
# 0  happy-lemon-markham  Xo1LNzhnwE-ilqsM3ybs9Q             3.5
# 1  happy-lemon-markham  Xo1LNzhnwE-ilqsM3ybs9Q             3.5
#
#                  categories  \
# 0  Bubble Tea, Coffee & Tea
# 1  Bubble Tea, Coffee & Tea
#
#                                                       coordinates        date  \
# 0  {'latitude': 43.8258200636421, 'longitude': -79.3063458055258}  2016-08-23
# 1  {'latitude': 43.8258200636421, 'longitude': -79.3063458055258}  2016-10-02
#
#      display_phone     distance  friend_count  ghost  \
# 0  +1 416-855-0768  2867.240253           105  False
# 1  +1 416-855-0768  2867.240253           171  False
#
#                                                               image_url  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/ATj6Mv5Siz8ExZpAC8XSXA/o.jpg
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/ATj6Mv5Siz8ExZpAC8XSXA/o.jpg
#
#                                                                                      img_dsc  \
# 0                          ['Photo of Happy Lemon - Markham, ON, Canada. Lemon mango slush']
# 1  ['Photo of Happy Lemon - Markham, ON, Canada. Oreo milk tea', 'Photo of Happy Lemon - ...
#
#                                                                                      img_url  \
# 0                ['https://s3-media4.fl.yelpcdn.com/bphoto/tu7jZIEA1RZJ6U1s7ZAx3w/348s.jpg']
# 1  ['https://s3-media3.fl.yelpcdn.com/bphoto/h110aP3Vldr7KjuhOhryZQ/348s.jpg', 'https://s...
#
#    index  is_closed          latitude  level_0  \
# 0  21653      False  43.8258200636421     5749
# 1  21653      False  43.8258200636421     5749
#
#                                                                                     location  \
# 0  {'address1': 'B25 4300 Steeles Avenue E', 'address2': '', 'address3': None, 'city': 'M...
# 1  {'address1': 'B25 4300 Steeles Avenue E', 'address2': '', 'address3': None, 'city': 'M...
#
#            longitude         name     nr         phone  photo_count price  \
# 0  -79.3063458055258  Happy Lemon  False  1.416855e+10        325.0     $
# 1  -79.3063458055258  Happy Lemon  False  1.416855e+10        307.0     $
#
#    review_count_x  review_count_y          review_date  \
# 0             122              32  ['8', '23', '2016']
# 1             114              32  ['10', '2', '2016']
#
#                 review_id review_language  stars  \
# 0  rqjzFEb1rQ09CgDVlGxZug              en    4.0
# 1  P7S5VclOJEihkqpA7LscPw              en    3.0
#
#                                                                                         text  \
# 0  I ordered the lemon mango slush and the lemon taste is very strong.  If you love lemon...
# 1  Came here on a Sunday afternoon, it wasn't busy at all. I came here for the Sunday spe...
#
#   transactions        ufc  \
# 0           []  [1, 1, 1]
# 1           []  [1, 0, 0]
#
#                                                                                          url  \
# 0  https://www.yelp.com/biz/happy-lemon-markham?adjust_creative=ZbO96qTvvfSmFTkvkUBjkQ&ut...
# 1  https://www.yelp.com/biz/happy-lemon-markham?adjust_creative=ZbO96qTvvfSmFTkvkUBjkQ&ut...
#
#                   user_id                            user_loc  vote_count
# 0  zsJFjhBQEFQ6gJ7BsNM_Ug                     Toronto, Canada         1.0
# 1  P7YuMh74-I2cDq7oU8frww  York Regional Municipality, Canada         1.0
